# %% [markdown]
# # Dataless Neural Network for MIS finding in Graphs

# %% [markdown]
# ## 1. Generate a random dense graph using NetworkX
# This will be the graph that we find the MIS of

# %%
import networkx as nx

NUMBER_OF_NODES = 50
NUMBER_OF_EDGES = 150
SEED = 13

G = nx.generators.dense_gnm_random_graph(NUMBER_OF_NODES, NUMBER_OF_EDGES, seed=SEED)

nx.draw(G,with_labels=True)

# %% [markdown]
# ## 2. Generate a neural network to solve your graph's MIS

# %% [markdown]
# ### Perform an optimization using the structure and weights to determine the MIS

# %%
import torch
import numpy
import time
from sam import SAM
from datalessNN import datalessNN_graph_params, datalessNN_module
from layer_constraints import ZeroOneClamp

initial_learning_rate = 0.01
training_steps = 3500

## generate graph weights
NN_graph_params = datalessNN_graph_params(G)

graph_order = len(G.nodes)

NN = datalessNN_module(
    NN_graph_params["theta_tensor"],
    NN_graph_params["layer_2_weights"],
    NN_graph_params["layer_2_biases"],
    NN_graph_params["layer_3_weights"])

################# optimization
# good and fast results on most is found at initial_learning_rate = 0.001
base_optimizer = torch.optim.Adam  # define an optimizer for the "sharpness-aware" update
optimizer = SAM(NN.parameters(), base_optimizer, lr=initial_learning_rate)

loss_fn = torch.nn.MSELoss()

theta_constraint = ZeroOneClamp()

##################################################################################################
##################################################################################################
##################################################################################################

batch_size_gen = 1
batch_size_2 = batch_size_gen

################################################################
##### X_train is the same for both gen and combined models #####
################################################################

X_train = numpy.ones(len(NN_graph_params["theta_tensor"]))

############################################################
### Y_train_combined is the v_d (desired value)
################################################################

P_desired = numpy.zeros(1)
P_desired[0] = -graph_order**2 / 2

print("P Desired", P_desired)

Y_train_combined = numpy.zeros(shape=(batch_size_2, 1, 1))

Y_val_combined = P_desired.reshape(1, 1)
for i in range(batch_size_2):
    Y_train_combined[i, :, :] = Y_val_combined

Y_train_combined = Y_train_combined.reshape(batch_size_2, 1)

Y_desired = torch.Tensor(Y_val_combined)
Y_val_combined = Y_val_combined.reshape(1, 1, 1)
Y_val_combined = Y_val_combined.reshape(1, 1)
# Y_val_combined = Y_val_combined.reshape(3)

################################################################
### train
################################################################
X_star = None

start = time.time()
for i in range(training_steps):
    predicted_y = NN(X_train)

    loss = loss_fn(predicted_y, Y_desired)
    loss.backward(retain_graph = True)
    optimizer.first_step(zero_grad=True)

    ## normalize theta values between 0 and 1
    NN[0].apply(theta_constraint)

    X_star = NN[0].weight

    if any(X_star > 1.0) or any(X_star < 0.0):
        print(f"exit AT training step = {i} --- THERE IS A A VALUE IN THE WEIGHTS OUTSIDE [0,1] --- x_star = {X_star}")
        break

    print(f"training_step = {i} --- value = {predicted_y.item():.4f} --- desired value set for optimization = {P_desired[0]}")

    loss_fn(predicted_y, Y_desired).backward()

    optimizer.second_step(zero_grad=True)

x_star = X_star.detach().numpy()

greater_than_09 = (x_star > 0.9).sum()
print(f"Size of MIS (theta > 0.9): {greater_than_09}")
nx.draw_networkx(G, node_color=x_star)
# Out:
# P Desired [-1250.]
# /home/cledenmat/Documents/Master's Research/datalessMISNotebook/.venv/lib64/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# training_step = 0 --- value = 283.6560 --- desired value set for optimization = -1250.0
# training_step = 1 --- value = 252.4514 --- desired value set for optimization = -1250.0
# training_step = 2 --- value = 226.2105 --- desired value set for optimization = -1250.0
# training_step = 3 --- value = 201.1142 --- desired value set for optimization = -1250.0
# training_step = 4 --- value = 176.0941 --- desired value set for optimization = -1250.0
# training_step = 5 --- value = 152.8114 --- desired value set for optimization = -1250.0
# training_step = 6 --- value = 131.2458 --- desired value set for optimization = -1250.0
# training_step = 7 --- value = 113.0531 --- desired value set for optimization = -1250.0
# training_step = 8 --- value = 98.7716 --- desired value set for optimization = -1250.0
# training_step = 9 --- value = 85.5170 --- desired value set for optimization = -1250.0
# training_step = 10 --- value = 72.5834 --- desired value set for optimization = -1250.0
# training_step = 11 --- value = 60.8652 --- desired value set for optimization = -1250.0
# training_step = 12 --- value = 49.6129 --- desired value set for optimization = -1250.0
# training_step = 13 --- value = 39.7917 --- desired value set for optimization = -1250.0
# training_step = 14 --- value = 31.0219 --- desired value set for optimization = -1250.0
# training_step = 15 --- value = 23.0459 --- desired value set for optimization = -1250.0
# training_step = 16 --- value = 15.2183 --- desired value set for optimization = -1250.0
# training_step = 17 --- value = 8.2035 --- desired value set for optimization = -1250.0
# training_step = 18 --- value = 2.4202 --- desired value set for optimization = -1250.0
# training_step = 19 --- value = -2.4359 --- desired value set for optimization = -1250.0
# training_step = 20 --- value = -6.3942 --- desired value set for optimization = -1250.0
# training_step = 21 --- value = -9.3162 --- desired value set for optimization = -1250.0
# training_step = 22 --- value = -12.9489 --- desired value set for optimization = -1250.0
# training_step = 23 --- value = -15.3836 --- desired value set for optimization = -1250.0
# training_step = 24 --- value = -17.8570 --- desired value set for optimization = -1250.0
# training_step = 25 --- value = -20.8101 --- desired value set for optimization = -1250.0
# training_step = 26 --- value = -24.0858 --- desired value set for optimization = -1250.0
# training_step = 27 --- value = -26.3550 --- desired value set for optimization = -1250.0
# training_step = 28 --- value = -28.0229 --- desired value set for optimization = -1250.0
# training_step = 29 --- value = -29.7346 --- desired value set for optimization = -1250.0
# training_step = 30 --- value = -31.7193 --- desired value set for optimization = -1250.0
# training_step = 31 --- value = -33.3834 --- desired value set for optimization = -1250.0
# training_step = 32 --- value = -34.9643 --- desired value set for optimization = -1250.0
# training_step = 33 --- value = -36.6303 --- desired value set for optimization = -1250.0
# training_step = 34 --- value = -38.4868 --- desired value set for optimization = -1250.0
# training_step = 35 --- value = -40.7479 --- desired value set for optimization = -1250.0
# training_step = 36 --- value = -43.2193 --- desired value set for optimization = -1250.0
# training_step = 37 --- value = -45.1683 --- desired value set for optimization = -1250.0
# training_step = 38 --- value = -47.2453 --- desired value set for optimization = -1250.0
# training_step = 39 --- value = -49.2302 --- desired value set for optimization = -1250.0
# training_step = 40 --- value = -50.3762 --- desired value set for optimization = -1250.0
# training_step = 41 --- value = -51.0711 --- desired value set for optimization = -1250.0
# training_step = 42 --- value = -52.2423 --- desired value set for optimization = -1250.0
# training_step = 43 --- value = -53.9126 --- desired value set for optimization = -1250.0
# training_step = 44 --- value = -55.4689 --- desired value set for optimization = -1250.0
# training_step = 45 --- value = -56.9917 --- desired value set for optimization = -1250.0
# training_step = 46 --- value = -58.8706 --- desired value set for optimization = -1250.0
# training_step = 47 --- value = -60.2529 --- desired value set for optimization = -1250.0
# training_step = 48 --- value = -61.6943 --- desired value set for optimization = -1250.0
# training_step = 49 --- value = -63.2649 --- desired value set for optimization = -1250.0
# training_step = 50 --- value = -64.7865 --- desired value set for optimization = -1250.0
# training_step = 51 --- value = -66.6078 --- desired value set for optimization = -1250.0
# training_step = 52 --- value = -68.2640 --- desired value set for optimization = -1250.0
# training_step = 53 --- value = -69.9926 --- desired value set for optimization = -1250.0
# training_step = 54 --- value = -71.4082 --- desired value set for optimization = -1250.0
# training_step = 55 --- value = -73.0069 --- desired value set for optimization = -1250.0
# training_step = 56 --- value = -74.9368 --- desired value set for optimization = -1250.0
# training_step = 57 --- value = -76.4317 --- desired value set for optimization = -1250.0
# training_step = 58 --- value = -77.6370 --- desired value set for optimization = -1250.0
# training_step = 59 --- value = -79.1612 --- desired value set for optimization = -1250.0
# training_step = 60 --- value = -80.9467 --- desired value set for optimization = -1250.0
# training_step = 61 --- value = -82.7805 --- desired value set for optimization = -1250.0
# training_step = 62 --- value = -83.9961 --- desired value set for optimization = -1250.0
# training_step = 63 --- value = -85.2792 --- desired value set for optimization = -1250.0
# training_step = 64 --- value = -86.5808 --- desired value set for optimization = -1250.0
# training_step = 65 --- value = -88.1376 --- desired value set for optimization = -1250.0
# training_step = 66 --- value = -89.7438 --- desired value set for optimization = -1250.0
# training_step = 67 --- value = -91.2937 --- desired value set for optimization = -1250.0
# training_step = 68 --- value = -93.5039 --- desired value set for optimization = -1250.0
# training_step = 69 --- value = -94.5222 --- desired value set for optimization = -1250.0
# training_step = 70 --- value = -95.4001 --- desired value set for optimization = -1250.0
# training_step = 71 --- value = -96.4048 --- desired value set for optimization = -1250.0
# training_step = 72 --- value = -97.5584 --- desired value set for optimization = -1250.0
# training_step = 73 --- value = -98.5876 --- desired value set for optimization = -1250.0
# training_step = 74 --- value = -100.4169 --- desired value set for optimization = -1250.0
# training_step = 75 --- value = -101.6268 --- desired value set for optimization = -1250.0
# training_step = 76 --- value = -102.6780 --- desired value set for optimization = -1250.0
# training_step = 77 --- value = -103.9459 --- desired value set for optimization = -1250.0
# training_step = 78 --- value = -105.0515 --- desired value set for optimization = -1250.0
# training_step = 79 --- value = -106.4416 --- desired value set for optimization = -1250.0
# training_step = 80 --- value = -108.0034 --- desired value set for optimization = -1250.0
# training_step = 81 --- value = -109.1895 --- desired value set for optimization = -1250.0
# training_step = 82 --- value = -110.3343 --- desired value set for optimization = -1250.0
# training_step = 83 --- value = -111.6485 --- desired value set for optimization = -1250.0
# training_step = 84 --- value = -112.0561 --- desired value set for optimization = -1250.0
# training_step = 85 --- value = -113.4608 --- desired value set for optimization = -1250.0
# training_step = 86 --- value = -115.1306 --- desired value set for optimization = -1250.0
# training_step = 87 --- value = -115.9993 --- desired value set for optimization = -1250.0
# training_step = 88 --- value = -117.1268 --- desired value set for optimization = -1250.0
# training_step = 89 --- value = -118.0969 --- desired value set for optimization = -1250.0
# training_step = 90 --- value = -119.1609 --- desired value set for optimization = -1250.0
# training_step = 91 --- value = -120.3344 --- desired value set for optimization = -1250.0
# training_step = 92 --- value = -121.3036 --- desired value set for optimization = -1250.0
# training_step = 93 --- value = -122.5183 --- desired value set for optimization = -1250.0
# training_step = 94 --- value = -123.8392 --- desired value set for optimization = -1250.0
# training_step = 95 --- value = -125.3004 --- desired value set for optimization = -1250.0
# training_step = 96 --- value = -126.0897 --- desired value set for optimization = -1250.0
# training_step = 97 --- value = -127.2795 --- desired value set for optimization = -1250.0
# training_step = 98 --- value = -128.2314 --- desired value set for optimization = -1250.0
# training_step = 99 --- value = -129.6726 --- desired value set for optimization = -1250.0
# training_step = 100 --- value = -130.7501 --- desired value set for optimization = -1250.0
# training_step = 101 --- value = -131.6709 --- desired value set for optimization = -1250.0
# training_step = 102 --- value = -132.9694 --- desired value set for optimization = -1250.0
# training_step = 103 --- value = -133.9434 --- desired value set for optimization = -1250.0
# training_step = 104 --- value = -134.9043 --- desired value set for optimization = -1250.0
# training_step = 105 --- value = -135.8138 --- desired value set for optimization = -1250.0
# training_step = 106 --- value = -137.0451 --- desired value set for optimization = -1250.0
# training_step = 107 --- value = -138.5152 --- desired value set for optimization = -1250.0
# training_step = 108 --- value = -139.4486 --- desired value set for optimization = -1250.0
# training_step = 109 --- value = -140.4255 --- desired value set for optimization = -1250.0
# training_step = 110 --- value = -140.9028 --- desired value set for optimization = -1250.0
# training_step = 111 --- value = -141.7997 --- desired value set for optimization = -1250.0
# training_step = 112 --- value = -142.1542 --- desired value set for optimization = -1250.0
# training_step = 113 --- value = -143.0411 --- desired value set for optimization = -1250.0
# training_step = 114 --- value = -143.7365 --- desired value set for optimization = -1250.0
# training_step = 115 --- value = -144.3574 --- desired value set for optimization = -1250.0
# training_step = 116 --- value = -145.0275 --- desired value set for optimization = -1250.0
# training_step = 117 --- value = -145.4288 --- desired value set for optimization = -1250.0
# training_step = 118 --- value = -146.6635 --- desired value set for optimization = -1250.0
# training_step = 119 --- value = -147.5548 --- desired value set for optimization = -1250.0
# training_step = 120 --- value = -148.1160 --- desired value set for optimization = -1250.0
# training_step = 121 --- value = -148.8326 --- desired value set for optimization = -1250.0
# training_step = 122 --- value = -149.2144 --- desired value set for optimization = -1250.0
# training_step = 123 --- value = -149.6038 --- desired value set for optimization = -1250.0
# training_step = 124 --- value = -150.0605 --- desired value set for optimization = -1250.0
# training_step = 125 --- value = -150.5086 --- desired value set for optimization = -1250.0
# training_step = 126 --- value = -151.1288 --- desired value set for optimization = -1250.0
# training_step = 127 --- value = -151.8083 --- desired value set for optimization = -1250.0
# training_step = 128 --- value = -152.0705 --- desired value set for optimization = -1250.0
# training_step = 129 --- value = -152.5957 --- desired value set for optimization = -1250.0
# training_step = 130 --- value = -152.8806 --- desired value set for optimization = -1250.0
# training_step = 131 --- value = -153.1282 --- desired value set for optimization = -1250.0
# training_step = 132 --- value = -153.7008 --- desired value set for optimization = -1250.0
# training_step = 133 --- value = -154.1818 --- desired value set for optimization = -1250.0
# training_step = 134 --- value = -154.6011 --- desired value set for optimization = -1250.0
# training_step = 135 --- value = -154.8050 --- desired value set for optimization = -1250.0
# training_step = 136 --- value = -155.0484 --- desired value set for optimization = -1250.0
# training_step = 137 --- value = -155.2443 --- desired value set for optimization = -1250.0
# training_step = 138 --- value = -155.7655 --- desired value set for optimization = -1250.0
# training_step = 139 --- value = -156.2768 --- desired value set for optimization = -1250.0
# training_step = 140 --- value = -156.4147 --- desired value set for optimization = -1250.0
# training_step = 141 --- value = -156.6935 --- desired value set for optimization = -1250.0
# training_step = 142 --- value = -157.1001 --- desired value set for optimization = -1250.0
# training_step = 143 --- value = -157.2152 --- desired value set for optimization = -1250.0
# training_step = 144 --- value = -157.3822 --- desired value set for optimization = -1250.0
# training_step = 145 --- value = -157.8917 --- desired value set for optimization = -1250.0
# training_step = 146 --- value = -157.9775 --- desired value set for optimization = -1250.0
# training_step = 147 --- value = -157.9699 --- desired value set for optimization = -1250.0
# training_step = 148 --- value = -157.9828 --- desired value set for optimization = -1250.0
# training_step = 149 --- value = -158.3482 --- desired value set for optimization = -1250.0
# training_step = 150 --- value = -158.8280 --- desired value set for optimization = -1250.0
# training_step = 151 --- value = -159.0685 --- desired value set for optimization = -1250.0
# training_step = 152 --- value = -159.2532 --- desired value set for optimization = -1250.0
# training_step = 153 --- value = -159.1658 --- desired value set for optimization = -1250.0
# training_step = 154 --- value = -159.7497 --- desired value set for optimization = -1250.0
# training_step = 155 --- value = -160.0714 --- desired value set for optimization = -1250.0
# training_step = 156 --- value = -160.2917 --- desired value set for optimization = -1250.0
# training_step = 157 --- value = -160.4845 --- desired value set for optimization = -1250.0
# training_step = 158 --- value = -160.6668 --- desired value set for optimization = -1250.0
# training_step = 159 --- value = -160.9945 --- desired value set for optimization = -1250.0
# training_step = 160 --- value = -161.1784 --- desired value set for optimization = -1250.0
# training_step = 161 --- value = -161.5184 --- desired value set for optimization = -1250.0
# training_step = 162 --- value = -161.9499 --- desired value set for optimization = -1250.0
# training_step = 163 --- value = -161.9651 --- desired value set for optimization = -1250.0
# training_step = 164 --- value = -162.2377 --- desired value set for optimization = -1250.0
# training_step = 165 --- value = -162.6218 --- desired value set for optimization = -1250.0
# training_step = 166 --- value = -163.1016 --- desired value set for optimization = -1250.0
# training_step = 167 --- value = -163.3850 --- desired value set for optimization = -1250.0
# training_step = 168 --- value = -163.4812 --- desired value set for optimization = -1250.0
# training_step = 169 --- value = -163.7661 --- desired value set for optimization = -1250.0
# training_step = 170 --- value = -164.2207 --- desired value set for optimization = -1250.0
# training_step = 171 --- value = -164.2837 --- desired value set for optimization = -1250.0
# training_step = 172 --- value = -164.4788 --- desired value set for optimization = -1250.0
# training_step = 173 --- value = -164.9375 --- desired value set for optimization = -1250.0
# training_step = 174 --- value = -165.1071 --- desired value set for optimization = -1250.0
# training_step = 175 --- value = -165.2451 --- desired value set for optimization = -1250.0
# training_step = 176 --- value = -165.6090 --- desired value set for optimization = -1250.0
# training_step = 177 --- value = -166.0665 --- desired value set for optimization = -1250.0
# training_step = 178 --- value = -165.9962 --- desired value set for optimization = -1250.0
# training_step = 179 --- value = -166.3089 --- desired value set for optimization = -1250.0
# training_step = 180 --- value = -166.4874 --- desired value set for optimization = -1250.0
# training_step = 181 --- value = -166.9154 --- desired value set for optimization = -1250.0
# training_step = 182 --- value = -167.1353 --- desired value set for optimization = -1250.0
# training_step = 183 --- value = -167.5096 --- desired value set for optimization = -1250.0
# training_step = 184 --- value = -167.9385 --- desired value set for optimization = -1250.0
# training_step = 185 --- value = -167.8719 --- desired value set for optimization = -1250.0
# training_step = 186 --- value = -168.2373 --- desired value set for optimization = -1250.0
# training_step = 187 --- value = -168.2788 --- desired value set for optimization = -1250.0
# training_step = 188 --- value = -168.8082 --- desired value set for optimization = -1250.0
# training_step = 189 --- value = -168.9398 --- desired value set for optimization = -1250.0
# training_step = 190 --- value = -168.7707 --- desired value set for optimization = -1250.0
# training_step = 191 --- value = -169.0071 --- desired value set for optimization = -1250.0
# training_step = 192 --- value = -169.1558 --- desired value set for optimization = -1250.0
# training_step = 193 --- value = -169.1443 --- desired value set for optimization = -1250.0
# training_step = 194 --- value = -169.3055 --- desired value set for optimization = -1250.0
# training_step = 195 --- value = -169.3212 --- desired value set for optimization = -1250.0
# training_step = 196 --- value = -169.2952 --- desired value set for optimization = -1250.0
# training_step = 197 --- value = -169.5328 --- desired value set for optimization = -1250.0
# training_step = 198 --- value = -169.7511 --- desired value set for optimization = -1250.0
# training_step = 199 --- value = -169.7069 --- desired value set for optimization = -1250.0
# training_step = 200 --- value = -169.6923 --- desired value set for optimization = -1250.0
# training_step = 201 --- value = -169.7614 --- desired value set for optimization = -1250.0
# training_step = 202 --- value = -169.9982 --- desired value set for optimization = -1250.0
# training_step = 203 --- value = -170.0645 --- desired value set for optimization = -1250.0
# training_step = 204 --- value = -169.9905 --- desired value set for optimization = -1250.0
# training_step = 205 --- value = -170.0612 --- desired value set for optimization = -1250.0
# training_step = 206 --- value = -170.1084 --- desired value set for optimization = -1250.0
# training_step = 207 --- value = -170.1846 --- desired value set for optimization = -1250.0
# training_step = 208 --- value = -170.3380 --- desired value set for optimization = -1250.0
# training_step = 209 --- value = -170.4933 --- desired value set for optimization = -1250.0
# training_step = 210 --- value = -170.3701 --- desired value set for optimization = -1250.0
# training_step = 211 --- value = -170.3925 --- desired value set for optimization = -1250.0
# training_step = 212 --- value = -170.4385 --- desired value set for optimization = -1250.0
# training_step = 213 --- value = -170.6480 --- desired value set for optimization = -1250.0
# training_step = 214 --- value = -170.7623 --- desired value set for optimization = -1250.0
# training_step = 215 --- value = -170.7751 --- desired value set for optimization = -1250.0
# training_step = 216 --- value = -170.8569 --- desired value set for optimization = -1250.0
# training_step = 217 --- value = -170.9421 --- desired value set for optimization = -1250.0
# training_step = 218 --- value = -171.0445 --- desired value set for optimization = -1250.0
# training_step = 219 --- value = -171.1561 --- desired value set for optimization = -1250.0
# training_step = 220 --- value = -171.2054 --- desired value set for optimization = -1250.0
# training_step = 221 --- value = -171.2715 --- desired value set for optimization = -1250.0
# training_step = 222 --- value = -171.4469 --- desired value set for optimization = -1250.0
# training_step = 223 --- value = -171.5565 --- desired value set for optimization = -1250.0
# training_step = 224 --- value = -171.3047 --- desired value set for optimization = -1250.0
# training_step = 225 --- value = -171.4082 --- desired value set for optimization = -1250.0
# training_step = 226 --- value = -171.4960 --- desired value set for optimization = -1250.0
# training_step = 227 --- value = -171.5513 --- desired value set for optimization = -1250.0
# training_step = 228 --- value = -171.4969 --- desired value set for optimization = -1250.0
# training_step = 229 --- value = -171.5735 --- desired value set for optimization = -1250.0
# training_step = 230 --- value = -171.6261 --- desired value set for optimization = -1250.0
# training_step = 231 --- value = -171.8643 --- desired value set for optimization = -1250.0
# training_step = 232 --- value = -171.7746 --- desired value set for optimization = -1250.0
# training_step = 233 --- value = -171.7921 --- desired value set for optimization = -1250.0
# training_step = 234 --- value = -171.8093 --- desired value set for optimization = -1250.0
# training_step = 235 --- value = -171.9688 --- desired value set for optimization = -1250.0
# training_step = 236 --- value = -171.8961 --- desired value set for optimization = -1250.0
# training_step = 237 --- value = -171.8710 --- desired value set for optimization = -1250.0
# training_step = 238 --- value = -171.8257 --- desired value set for optimization = -1250.0
# training_step = 239 --- value = -171.9056 --- desired value set for optimization = -1250.0
# training_step = 240 --- value = -172.0454 --- desired value set for optimization = -1250.0
# training_step = 241 --- value = -171.9734 --- desired value set for optimization = -1250.0
# training_step = 242 --- value = -171.9867 --- desired value set for optimization = -1250.0
# training_step = 243 --- value = -172.0542 --- desired value set for optimization = -1250.0
# training_step = 244 --- value = -172.1960 --- desired value set for optimization = -1250.0
# training_step = 245 --- value = -172.1679 --- desired value set for optimization = -1250.0
# training_step = 246 --- value = -172.2169 --- desired value set for optimization = -1250.0
# training_step = 247 --- value = -172.2263 --- desired value set for optimization = -1250.0
# training_step = 248 --- value = -172.3200 --- desired value set for optimization = -1250.0
# training_step = 249 --- value = -172.2818 --- desired value set for optimization = -1250.0
# training_step = 250 --- value = -172.3313 --- desired value set for optimization = -1250.0
# training_step = 251 --- value = -172.5010 --- desired value set for optimization = -1250.0
# training_step = 252 --- value = -172.5439 --- desired value set for optimization = -1250.0
# training_step = 253 --- value = -172.3955 --- desired value set for optimization = -1250.0
# training_step = 254 --- value = -172.3852 --- desired value set for optimization = -1250.0
# training_step = 255 --- value = -172.4784 --- desired value set for optimization = -1250.0
# training_step = 256 --- value = -172.4869 --- desired value set for optimization = -1250.0
# training_step = 257 --- value = -172.5488 --- desired value set for optimization = -1250.0
# training_step = 258 --- value = -172.3257 --- desired value set for optimization = -1250.0
# training_step = 259 --- value = -172.5137 --- desired value set for optimization = -1250.0
# training_step = 260 --- value = -172.5831 --- desired value set for optimization = -1250.0
# training_step = 261 --- value = -172.8145 --- desired value set for optimization = -1250.0
# training_step = 262 --- value = -172.9054 --- desired value set for optimization = -1250.0
# training_step = 263 --- value = -172.6464 --- desired value set for optimization = -1250.0
# training_step = 264 --- value = -172.7003 --- desired value set for optimization = -1250.0
# training_step = 265 --- value = -172.6581 --- desired value set for optimization = -1250.0
# training_step = 266 --- value = -172.6456 --- desired value set for optimization = -1250.0
# training_step = 267 --- value = -172.7404 --- desired value set for optimization = -1250.0
# training_step = 268 --- value = -172.8105 --- desired value set for optimization = -1250.0
# training_step = 269 --- value = -172.9299 --- desired value set for optimization = -1250.0
# training_step = 270 --- value = -172.8746 --- desired value set for optimization = -1250.0
# training_step = 271 --- value = -173.0094 --- desired value set for optimization = -1250.0
# training_step = 272 --- value = -173.2240 --- desired value set for optimization = -1250.0
# training_step = 273 --- value = -173.0369 --- desired value set for optimization = -1250.0
# training_step = 274 --- value = -173.0540 --- desired value set for optimization = -1250.0
# training_step = 275 --- value = -173.1676 --- desired value set for optimization = -1250.0
# training_step = 276 --- value = -173.3539 --- desired value set for optimization = -1250.0
# training_step = 277 --- value = -173.5309 --- desired value set for optimization = -1250.0
# training_step = 278 --- value = -173.4635 --- desired value set for optimization = -1250.0
# training_step = 279 --- value = -173.4000 --- desired value set for optimization = -1250.0
# training_step = 280 --- value = -173.4090 --- desired value set for optimization = -1250.0
# training_step = 281 --- value = -173.4503 --- desired value set for optimization = -1250.0
# training_step = 282 --- value = -173.5181 --- desired value set for optimization = -1250.0
# training_step = 283 --- value = -173.5157 --- desired value set for optimization = -1250.0
# training_step = 284 --- value = -173.6019 --- desired value set for optimization = -1250.0
# training_step = 285 --- value = -173.7136 --- desired value set for optimization = -1250.0
# training_step = 286 --- value = -173.6198 --- desired value set for optimization = -1250.0
# training_step = 287 --- value = -173.6673 --- desired value set for optimization = -1250.0
# training_step = 288 --- value = -173.7568 --- desired value set for optimization = -1250.0
# training_step = 289 --- value = -173.6700 --- desired value set for optimization = -1250.0
# training_step = 290 --- value = -173.7552 --- desired value set for optimization = -1250.0
# training_step = 291 --- value = -173.7304 --- desired value set for optimization = -1250.0
# training_step = 292 --- value = -173.7104 --- desired value set for optimization = -1250.0
# training_step = 293 --- value = -174.0018 --- desired value set for optimization = -1250.0
# training_step = 294 --- value = -173.9683 --- desired value set for optimization = -1250.0
# training_step = 295 --- value = -173.8952 --- desired value set for optimization = -1250.0
# training_step = 296 --- value = -174.0369 --- desired value set for optimization = -1250.0
# training_step = 297 --- value = -174.0219 --- desired value set for optimization = -1250.0
# training_step = 298 --- value = -173.9205 --- desired value set for optimization = -1250.0
# training_step = 299 --- value = -173.9217 --- desired value set for optimization = -1250.0
# training_step = 300 --- value = -173.8943 --- desired value set for optimization = -1250.0
# training_step = 301 --- value = -174.0105 --- desired value set for optimization = -1250.0
# training_step = 302 --- value = -174.1084 --- desired value set for optimization = -1250.0
# training_step = 303 --- value = -174.2451 --- desired value set for optimization = -1250.0
# training_step = 304 --- value = -174.0697 --- desired value set for optimization = -1250.0
# training_step = 305 --- value = -174.0859 --- desired value set for optimization = -1250.0
# training_step = 306 --- value = -174.3014 --- desired value set for optimization = -1250.0
# training_step = 307 --- value = -174.5816 --- desired value set for optimization = -1250.0
# training_step = 308 --- value = -174.4887 --- desired value set for optimization = -1250.0
# training_step = 309 --- value = -174.5190 --- desired value set for optimization = -1250.0
# training_step = 310 --- value = -174.4250 --- desired value set for optimization = -1250.0
# training_step = 311 --- value = -174.5758 --- desired value set for optimization = -1250.0
# training_step = 312 --- value = -174.5952 --- desired value set for optimization = -1250.0
# training_step = 313 --- value = -174.5755 --- desired value set for optimization = -1250.0
# training_step = 314 --- value = -174.6274 --- desired value set for optimization = -1250.0
# training_step = 315 --- value = -174.6901 --- desired value set for optimization = -1250.0
# training_step = 316 --- value = -174.6982 --- desired value set for optimization = -1250.0
# training_step = 317 --- value = -174.8047 --- desired value set for optimization = -1250.0
# training_step = 318 --- value = -174.8083 --- desired value set for optimization = -1250.0
# training_step = 319 --- value = -174.9721 --- desired value set for optimization = -1250.0
# training_step = 320 --- value = -174.8300 --- desired value set for optimization = -1250.0
# training_step = 321 --- value = -174.7610 --- desired value set for optimization = -1250.0
# training_step = 322 --- value = -174.8951 --- desired value set for optimization = -1250.0
# training_step = 323 --- value = -175.1184 --- desired value set for optimization = -1250.0
# training_step = 324 --- value = -174.9790 --- desired value set for optimization = -1250.0
# training_step = 325 --- value = -174.8891 --- desired value set for optimization = -1250.0
# training_step = 326 --- value = -174.9669 --- desired value set for optimization = -1250.0
# training_step = 327 --- value = -175.0187 --- desired value set for optimization = -1250.0
# training_step = 328 --- value = -175.1136 --- desired value set for optimization = -1250.0
# training_step = 329 --- value = -175.1425 --- desired value set for optimization = -1250.0
# training_step = 330 --- value = -175.2021 --- desired value set for optimization = -1250.0
# training_step = 331 --- value = -175.2059 --- desired value set for optimization = -1250.0
# training_step = 332 --- value = -175.2995 --- desired value set for optimization = -1250.0
# training_step = 333 --- value = -175.3079 --- desired value set for optimization = -1250.0
# training_step = 334 --- value = -175.3386 --- desired value set for optimization = -1250.0
# training_step = 335 --- value = -175.4540 --- desired value set for optimization = -1250.0
# training_step = 336 --- value = -175.4098 --- desired value set for optimization = -1250.0
# training_step = 337 --- value = -175.3516 --- desired value set for optimization = -1250.0
# training_step = 338 --- value = -175.3286 --- desired value set for optimization = -1250.0
# training_step = 339 --- value = -175.3530 --- desired value set for optimization = -1250.0
# training_step = 340 --- value = -175.6026 --- desired value set for optimization = -1250.0
# training_step = 341 --- value = -175.5563 --- desired value set for optimization = -1250.0
# training_step = 342 --- value = -175.5822 --- desired value set for optimization = -1250.0
# training_step = 343 --- value = -175.6425 --- desired value set for optimization = -1250.0
# training_step = 344 --- value = -175.6418 --- desired value set for optimization = -1250.0
# training_step = 345 --- value = -175.7648 --- desired value set for optimization = -1250.0
# training_step = 346 --- value = -175.6703 --- desired value set for optimization = -1250.0
# training_step = 347 --- value = -175.6661 --- desired value set for optimization = -1250.0
# training_step = 348 --- value = -175.7982 --- desired value set for optimization = -1250.0
# training_step = 349 --- value = -175.7993 --- desired value set for optimization = -1250.0
# training_step = 350 --- value = -175.8000 --- desired value set for optimization = -1250.0
# training_step = 351 --- value = -175.8236 --- desired value set for optimization = -1250.0
# training_step = 352 --- value = -175.9299 --- desired value set for optimization = -1250.0
# training_step = 353 --- value = -176.0310 --- desired value set for optimization = -1250.0
# training_step = 354 --- value = -175.9002 --- desired value set for optimization = -1250.0
# training_step = 355 --- value = -175.8722 --- desired value set for optimization = -1250.0
# training_step = 356 --- value = -175.9497 --- desired value set for optimization = -1250.0
# training_step = 357 --- value = -176.0835 --- desired value set for optimization = -1250.0
# training_step = 358 --- value = -176.1516 --- desired value set for optimization = -1250.0
# training_step = 359 --- value = -176.1132 --- desired value set for optimization = -1250.0
# training_step = 360 --- value = -176.1086 --- desired value set for optimization = -1250.0
# training_step = 361 --- value = -176.2122 --- desired value set for optimization = -1250.0
# training_step = 362 --- value = -176.0825 --- desired value set for optimization = -1250.0
# training_step = 363 --- value = -176.1293 --- desired value set for optimization = -1250.0
# training_step = 364 --- value = -176.3161 --- desired value set for optimization = -1250.0
# training_step = 365 --- value = -176.4003 --- desired value set for optimization = -1250.0
# training_step = 366 --- value = -176.3772 --- desired value set for optimization = -1250.0
# training_step = 367 --- value = -176.4926 --- desired value set for optimization = -1250.0
# training_step = 368 --- value = -176.5910 --- desired value set for optimization = -1250.0
# training_step = 369 --- value = -176.7168 --- desired value set for optimization = -1250.0
# training_step = 370 --- value = -176.6792 --- desired value set for optimization = -1250.0
# training_step = 371 --- value = -176.5675 --- desired value set for optimization = -1250.0
# training_step = 372 --- value = -176.7178 --- desired value set for optimization = -1250.0
# training_step = 373 --- value = -176.6258 --- desired value set for optimization = -1250.0
# training_step = 374 --- value = -176.7598 --- desired value set for optimization = -1250.0
# training_step = 375 --- value = -176.9368 --- desired value set for optimization = -1250.0
# training_step = 376 --- value = -176.9814 --- desired value set for optimization = -1250.0
# training_step = 377 --- value = -177.0379 --- desired value set for optimization = -1250.0
# training_step = 378 --- value = -177.0054 --- desired value set for optimization = -1250.0
# training_step = 379 --- value = -176.9578 --- desired value set for optimization = -1250.0
# training_step = 380 --- value = -177.0304 --- desired value set for optimization = -1250.0
# training_step = 381 --- value = -177.1935 --- desired value set for optimization = -1250.0
# training_step = 382 --- value = -177.0974 --- desired value set for optimization = -1250.0
# training_step = 383 --- value = -177.0627 --- desired value set for optimization = -1250.0
# training_step = 384 --- value = -177.0977 --- desired value set for optimization = -1250.0
# training_step = 385 --- value = -177.1922 --- desired value set for optimization = -1250.0
# training_step = 386 --- value = -177.3163 --- desired value set for optimization = -1250.0
# training_step = 387 --- value = -177.4416 --- desired value set for optimization = -1250.0
# training_step = 388 --- value = -177.3646 --- desired value set for optimization = -1250.0
# training_step = 389 --- value = -177.3869 --- desired value set for optimization = -1250.0
# training_step = 390 --- value = -177.2895 --- desired value set for optimization = -1250.0
# training_step = 391 --- value = -177.4389 --- desired value set for optimization = -1250.0
# training_step = 392 --- value = -177.5334 --- desired value set for optimization = -1250.0
# training_step = 393 --- value = -177.5131 --- desired value set for optimization = -1250.0
# training_step = 394 --- value = -177.5522 --- desired value set for optimization = -1250.0
# training_step = 395 --- value = -177.4866 --- desired value set for optimization = -1250.0
# training_step = 396 --- value = -177.5475 --- desired value set for optimization = -1250.0
# training_step = 397 --- value = -177.7456 --- desired value set for optimization = -1250.0
# training_step = 398 --- value = -177.7713 --- desired value set for optimization = -1250.0
# training_step = 399 --- value = -177.8381 --- desired value set for optimization = -1250.0
# training_step = 400 --- value = -177.7595 --- desired value set for optimization = -1250.0
# training_step = 401 --- value = -177.9010 --- desired value set for optimization = -1250.0
# training_step = 402 --- value = -177.9605 --- desired value set for optimization = -1250.0
# training_step = 403 --- value = -177.9537 --- desired value set for optimization = -1250.0
# training_step = 404 --- value = -177.7807 --- desired value set for optimization = -1250.0
# training_step = 405 --- value = -177.9871 --- desired value set for optimization = -1250.0
# training_step = 406 --- value = -178.0884 --- desired value set for optimization = -1250.0
# training_step = 407 --- value = -178.2225 --- desired value set for optimization = -1250.0
# training_step = 408 --- value = -178.1954 --- desired value set for optimization = -1250.0
# training_step = 409 --- value = -178.1348 --- desired value set for optimization = -1250.0
# training_step = 410 --- value = -178.2023 --- desired value set for optimization = -1250.0
# training_step = 411 --- value = -178.3415 --- desired value set for optimization = -1250.0
# training_step = 412 --- value = -178.1567 --- desired value set for optimization = -1250.0
# training_step = 413 --- value = -178.3545 --- desired value set for optimization = -1250.0
# training_step = 414 --- value = -178.3973 --- desired value set for optimization = -1250.0
# training_step = 415 --- value = -178.3852 --- desired value set for optimization = -1250.0
# training_step = 416 --- value = -178.3575 --- desired value set for optimization = -1250.0
# training_step = 417 --- value = -178.2672 --- desired value set for optimization = -1250.0
# training_step = 418 --- value = -178.2437 --- desired value set for optimization = -1250.0
# training_step = 419 --- value = -178.3907 --- desired value set for optimization = -1250.0
# training_step = 420 --- value = -178.6149 --- desired value set for optimization = -1250.0
# training_step = 421 --- value = -178.5766 --- desired value set for optimization = -1250.0
# training_step = 422 --- value = -178.5970 --- desired value set for optimization = -1250.0
# training_step = 423 --- value = -178.7045 --- desired value set for optimization = -1250.0
# training_step = 424 --- value = -178.9225 --- desired value set for optimization = -1250.0
# training_step = 425 --- value = -178.8693 --- desired value set for optimization = -1250.0
# training_step = 426 --- value = -178.8457 --- desired value set for optimization = -1250.0
# training_step = 427 --- value = -178.8218 --- desired value set for optimization = -1250.0
# training_step = 428 --- value = -178.7920 --- desired value set for optimization = -1250.0
# training_step = 429 --- value = -178.8879 --- desired value set for optimization = -1250.0
# training_step = 430 --- value = -178.9950 --- desired value set for optimization = -1250.0
# training_step = 431 --- value = -178.9377 --- desired value set for optimization = -1250.0
# training_step = 432 --- value = -178.9488 --- desired value set for optimization = -1250.0
# training_step = 433 --- value = -178.9706 --- desired value set for optimization = -1250.0
# training_step = 434 --- value = -179.0859 --- desired value set for optimization = -1250.0
# training_step = 435 --- value = -179.0926 --- desired value set for optimization = -1250.0
# training_step = 436 --- value = -179.0631 --- desired value set for optimization = -1250.0
# training_step = 437 --- value = -179.0908 --- desired value set for optimization = -1250.0
# training_step = 438 --- value = -179.1752 --- desired value set for optimization = -1250.0
# training_step = 439 --- value = -179.1308 --- desired value set for optimization = -1250.0
# training_step = 440 --- value = -179.1152 --- desired value set for optimization = -1250.0
# training_step = 441 --- value = -179.1717 --- desired value set for optimization = -1250.0
# training_step = 442 --- value = -179.1906 --- desired value set for optimization = -1250.0
# training_step = 443 --- value = -179.1400 --- desired value set for optimization = -1250.0
# training_step = 444 --- value = -179.1159 --- desired value set for optimization = -1250.0
# training_step = 445 --- value = -179.0942 --- desired value set for optimization = -1250.0
# training_step = 446 --- value = -179.0938 --- desired value set for optimization = -1250.0
# training_step = 447 --- value = -179.1079 --- desired value set for optimization = -1250.0
# training_step = 448 --- value = -179.1432 --- desired value set for optimization = -1250.0
# training_step = 449 --- value = -179.2156 --- desired value set for optimization = -1250.0
# training_step = 450 --- value = -179.0808 --- desired value set for optimization = -1250.0
# training_step = 451 --- value = -179.0617 --- desired value set for optimization = -1250.0
# training_step = 452 --- value = -179.1782 --- desired value set for optimization = -1250.0
# training_step = 453 --- value = -179.2636 --- desired value set for optimization = -1250.0
# training_step = 454 --- value = -179.2097 --- desired value set for optimization = -1250.0
# training_step = 455 --- value = -179.1332 --- desired value set for optimization = -1250.0
# training_step = 456 --- value = -179.1828 --- desired value set for optimization = -1250.0
# training_step = 457 --- value = -179.2697 --- desired value set for optimization = -1250.0
# training_step = 458 --- value = -179.2465 --- desired value set for optimization = -1250.0
# training_step = 459 --- value = -179.2043 --- desired value set for optimization = -1250.0
# training_step = 460 --- value = -179.2700 --- desired value set for optimization = -1250.0
# training_step = 461 --- value = -179.2105 --- desired value set for optimization = -1250.0
# training_step = 462 --- value = -179.2505 --- desired value set for optimization = -1250.0
# training_step = 463 --- value = -179.2663 --- desired value set for optimization = -1250.0
# training_step = 464 --- value = -179.2069 --- desired value set for optimization = -1250.0
# training_step = 465 --- value = -179.2450 --- desired value set for optimization = -1250.0
# training_step = 466 --- value = -179.1719 --- desired value set for optimization = -1250.0
# training_step = 467 --- value = -179.1500 --- desired value set for optimization = -1250.0
# training_step = 468 --- value = -179.1410 --- desired value set for optimization = -1250.0
# training_step = 469 --- value = -179.2387 --- desired value set for optimization = -1250.0
# training_step = 470 --- value = -179.2214 --- desired value set for optimization = -1250.0
# training_step = 471 --- value = -179.2263 --- desired value set for optimization = -1250.0
# training_step = 472 --- value = -179.1784 --- desired value set for optimization = -1250.0
# training_step = 473 --- value = -179.2303 --- desired value set for optimization = -1250.0
# training_step = 474 --- value = -179.2461 --- desired value set for optimization = -1250.0
# training_step = 475 --- value = -179.3554 --- desired value set for optimization = -1250.0
# training_step = 476 --- value = -179.3194 --- desired value set for optimization = -1250.0
# training_step = 477 --- value = -179.2430 --- desired value set for optimization = -1250.0
# training_step = 478 --- value = -179.2655 --- desired value set for optimization = -1250.0
# training_step = 479 --- value = -179.2679 --- desired value set for optimization = -1250.0
# training_step = 480 --- value = -179.3001 --- desired value set for optimization = -1250.0
# training_step = 481 --- value = -179.3541 --- desired value set for optimization = -1250.0
# training_step = 482 --- value = -179.4305 --- desired value set for optimization = -1250.0
# training_step = 483 --- value = -179.4446 --- desired value set for optimization = -1250.0
# training_step = 484 --- value = -179.4800 --- desired value set for optimization = -1250.0
# training_step = 485 --- value = -179.4103 --- desired value set for optimization = -1250.0
# training_step = 486 --- value = -179.4004 --- desired value set for optimization = -1250.0
# training_step = 487 --- value = -179.4827 --- desired value set for optimization = -1250.0
# training_step = 488 --- value = -179.3765 --- desired value set for optimization = -1250.0
# training_step = 489 --- value = -179.3425 --- desired value set for optimization = -1250.0
# training_step = 490 --- value = -179.3893 --- desired value set for optimization = -1250.0
# training_step = 491 --- value = -179.3870 --- desired value set for optimization = -1250.0
# training_step = 492 --- value = -179.4334 --- desired value set for optimization = -1250.0
# training_step = 493 --- value = -179.4610 --- desired value set for optimization = -1250.0
# training_step = 494 --- value = -179.4016 --- desired value set for optimization = -1250.0
# training_step = 495 --- value = -179.3376 --- desired value set for optimization = -1250.0
# training_step = 496 --- value = -179.3442 --- desired value set for optimization = -1250.0
# training_step = 497 --- value = -179.4416 --- desired value set for optimization = -1250.0
# training_step = 498 --- value = -179.4134 --- desired value set for optimization = -1250.0
# training_step = 499 --- value = -179.3627 --- desired value set for optimization = -1250.0
# training_step = 500 --- value = -179.3329 --- desired value set for optimization = -1250.0
# training_step = 501 --- value = -179.3468 --- desired value set for optimization = -1250.0
# training_step = 502 --- value = -179.3584 --- desired value set for optimization = -1250.0
# training_step = 503 --- value = -179.4175 --- desired value set for optimization = -1250.0
# training_step = 504 --- value = -179.4651 --- desired value set for optimization = -1250.0
# training_step = 505 --- value = -179.4459 --- desired value set for optimization = -1250.0
# training_step = 506 --- value = -179.3719 --- desired value set for optimization = -1250.0
# training_step = 507 --- value = -179.3707 --- desired value set for optimization = -1250.0
# training_step = 508 --- value = -179.4615 --- desired value set for optimization = -1250.0
# training_step = 509 --- value = -179.4502 --- desired value set for optimization = -1250.0
# training_step = 510 --- value = -179.3781 --- desired value set for optimization = -1250.0
# training_step = 511 --- value = -179.3494 --- desired value set for optimization = -1250.0
# training_step = 512 --- value = -179.3995 --- desired value set for optimization = -1250.0
# training_step = 513 --- value = -179.4156 --- desired value set for optimization = -1250.0
# training_step = 514 --- value = -179.4788 --- desired value set for optimization = -1250.0
# training_step = 515 --- value = -179.4862 --- desired value set for optimization = -1250.0
# training_step = 516 --- value = -179.3834 --- desired value set for optimization = -1250.0
# training_step = 517 --- value = -179.3529 --- desired value set for optimization = -1250.0
# training_step = 518 --- value = -179.3494 --- desired value set for optimization = -1250.0
# training_step = 519 --- value = -179.4385 --- desired value set for optimization = -1250.0
# training_step = 520 --- value = -179.5283 --- desired value set for optimization = -1250.0
# training_step = 521 --- value = -179.4021 --- desired value set for optimization = -1250.0
# training_step = 522 --- value = -179.3737 --- desired value set for optimization = -1250.0
# training_step = 523 --- value = -179.4471 --- desired value set for optimization = -1250.0
# training_step = 524 --- value = -179.4309 --- desired value set for optimization = -1250.0
# ...
# training_step = 3327 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3328 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3329 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3330 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3331 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3332 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3333 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3334 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3335 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3336 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3337 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3338 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3339 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3340 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3341 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3342 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3343 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3344 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3345 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3346 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3347 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3348 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3349 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3350 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3351 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3352 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3353 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3354 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3355 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3356 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3357 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3358 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3359 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3360 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3361 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3362 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3363 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3364 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3365 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3366 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3367 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3368 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3369 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3370 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3371 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3372 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3373 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3374 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3375 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3376 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3377 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3378 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3379 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3380 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3381 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3382 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3383 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3384 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3385 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3386 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3387 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3388 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3389 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3390 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3391 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3392 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3393 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3394 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3395 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3396 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3397 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3398 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3399 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3400 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3401 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3402 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3403 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3404 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3405 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3406 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3407 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3408 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3409 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3410 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3411 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3412 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3413 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3414 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3415 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3416 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3417 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3418 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3419 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3420 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3421 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3422 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3423 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3424 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3425 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3426 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3427 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3428 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3429 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3430 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3431 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3432 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3433 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3434 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3435 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3436 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3437 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3438 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3439 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3440 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3441 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3442 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3443 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3444 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3445 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3446 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3447 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3448 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3449 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3450 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3451 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3452 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3453 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3454 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3455 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3456 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3457 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3458 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3459 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3460 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3461 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3462 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3463 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3464 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3465 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3466 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3467 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3468 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3469 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3470 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3471 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3472 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3473 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3474 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3475 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3476 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3477 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3478 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3479 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3480 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3481 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3482 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3483 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3484 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3485 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3486 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3487 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3488 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3489 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3490 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3491 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3492 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3493 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3494 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3495 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3496 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3497 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3498 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 3499 --- value = -180.5000 --- desired value set for optimization = -1250.0
# Size of MIS (theta > 0.9): 19
