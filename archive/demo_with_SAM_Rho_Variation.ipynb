# %% [markdown]
# # Dataless Neural Network for MIS finding in Graphs

# %% [markdown]
# ## 1. Generate a random dense graph using NetworkX
# This will be the graph that we find the MIS of

# %%
import networkx as nx

NUMBER_OF_NODES = 50
NUMBER_OF_EDGES = 150
SEED = 13

G = nx.generators.dense_gnm_random_graph(NUMBER_OF_NODES, NUMBER_OF_EDGES, seed=SEED)

nx.draw(G,with_labels=True)

# %% [markdown]
# ## 2. Generate a neural network to solve your graph's MIS

# %% [markdown]
# ### Perform an optimization using the structure and weights to determine the MIS

# %%
import torch
import numpy
import time
from sam import SAM
from datalessNN import datalessNN_graph_params, datalessNN_module
from layer_constraints import ZeroOneClamp

training_stages = [{"steps": 3500, "rho": 10}, {"steps": 2000, "rho": 10}, {"steps": 1000, "rho": 100}]
initial_learning_rate = 0.1
batch_size_gen = 1
batch_size_2 = batch_size_gen

## generate graph weights
NN_graph_params = datalessNN_graph_params(G)

graph_order = len(G.nodes)

NN = datalessNN_module(
    NN_graph_params["theta_tensor"],
    NN_graph_params["layer_2_weights"],
    NN_graph_params["layer_2_biases"],
    NN_graph_params["layer_3_weights"])

################################################################
##### X_train is the same for both gen and combined models #####
################################################################

X_train = numpy.ones(len(NN_graph_params["theta_tensor"]))

############################################################
### Y_train_combined is the v_d (desired value)
################################################################

P_desired = numpy.zeros(1)
P_desired[0] = -graph_order**2 / 2

print("P Desired", P_desired)

Y_train_combined = numpy.zeros(shape=(batch_size_2, 1, 1))

Y_val_combined = P_desired.reshape(1, 1)
for i in range(batch_size_2):
    Y_train_combined[i, :, :] = Y_val_combined

Y_train_combined = Y_train_combined.reshape(batch_size_2, 1)

Y_desired = torch.Tensor(Y_val_combined)
Y_val_combined = Y_val_combined.reshape(1, 1, 1)
Y_val_combined = Y_val_combined.reshape(1, 1)
# Y_val_combined = Y_val_combined.reshape(3)

for stage in training_stages:
    ################# optimization
    # good and fast results on most is found at initial_learning_rate = 0.001
    base_optimizer = torch.optim.Adam  # define an optimizer for the "sharpness-aware" update
    optimizer = SAM(NN.parameters(), base_optimizer, lr=initial_learning_rate, rho=stage["rho"])

    loss_fn = torch.nn.MSELoss()

    theta_constraint = ZeroOneClamp()

    ################################################################
    ### train
    ################################################################
    X_star = None

    start = time.time()
    for i in range(stage["steps"]):
        predicted_y = NN(X_train)

        loss = loss_fn(predicted_y, Y_desired)
        loss.backward(retain_graph = True)
        optimizer.first_step(zero_grad=True)

        ## normalize theta values between 0 and 1
        NN[0].apply(theta_constraint)

        X_star = NN[0].weight

        if any(X_star > 1.0) or any(X_star < 0.0):
            print(f"exit AT training step = {i} --- THERE IS A A VALUE IN THE WEIGHTS OUTSIDE [0,1] --- x_star = {X_star}")
            break

        print(f"training_step = {i} --- value = {predicted_y.item():.4f} --- desired value set for optimization = {P_desired[0]}")

        loss_fn(predicted_y, Y_desired).backward()

        optimizer.second_step(zero_grad=True)

x_star = X_star.detach().numpy()

greater_than_09 = (x_star > 0.9).sum()
print(f"Size of MIS (theta > 0.9): {greater_than_09}")
nx.draw_networkx(G, node_color=x_star)
# Out:
# P Desired [-1250.]
# /home/cledenmat/Documents/Master's Research/datalessMISNotebook/.venv/lib64/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# training_step = 0 --- value = 283.6560 --- desired value set for optimization = -1250.0
# training_step = 1 --- value = 75.7297 --- desired value set for optimization = -1250.0
# training_step = 2 --- value = -0.9026 --- desired value set for optimization = -1250.0
# training_step = 3 --- value = -5.0009 --- desired value set for optimization = -1250.0
# training_step = 4 --- value = -7.6656 --- desired value set for optimization = -1250.0
# training_step = 5 --- value = -8.3163 --- desired value set for optimization = -1250.0
# training_step = 6 --- value = -8.0670 --- desired value set for optimization = -1250.0
# training_step = 7 --- value = -12.1390 --- desired value set for optimization = -1250.0
# training_step = 8 --- value = -14.9905 --- desired value set for optimization = -1250.0
# training_step = 9 --- value = -19.0750 --- desired value set for optimization = -1250.0
# training_step = 10 --- value = -22.9676 --- desired value set for optimization = -1250.0
# training_step = 11 --- value = -28.3951 --- desired value set for optimization = -1250.0
# training_step = 12 --- value = -33.5164 --- desired value set for optimization = -1250.0
# training_step = 13 --- value = -38.9865 --- desired value set for optimization = -1250.0
# training_step = 14 --- value = -42.8017 --- desired value set for optimization = -1250.0
# training_step = 15 --- value = -47.5332 --- desired value set for optimization = -1250.0
# training_step = 16 --- value = -53.4501 --- desired value set for optimization = -1250.0
# training_step = 17 --- value = -57.4016 --- desired value set for optimization = -1250.0
# training_step = 18 --- value = -63.0139 --- desired value set for optimization = -1250.0
# training_step = 19 --- value = -67.7374 --- desired value set for optimization = -1250.0
# training_step = 20 --- value = -70.9406 --- desired value set for optimization = -1250.0
# training_step = 21 --- value = -74.6172 --- desired value set for optimization = -1250.0
# training_step = 22 --- value = -78.9320 --- desired value set for optimization = -1250.0
# training_step = 23 --- value = -82.5097 --- desired value set for optimization = -1250.0
# training_step = 24 --- value = -86.7914 --- desired value set for optimization = -1250.0
# training_step = 25 --- value = -91.8560 --- desired value set for optimization = -1250.0
# training_step = 26 --- value = -97.4275 --- desired value set for optimization = -1250.0
# training_step = 27 --- value = -104.3263 --- desired value set for optimization = -1250.0
# training_step = 28 --- value = -111.3208 --- desired value set for optimization = -1250.0
# training_step = 29 --- value = -117.7338 --- desired value set for optimization = -1250.0
# training_step = 30 --- value = -125.4991 --- desired value set for optimization = -1250.0
# training_step = 31 --- value = -132.7884 --- desired value set for optimization = -1250.0
# training_step = 32 --- value = -139.2719 --- desired value set for optimization = -1250.0
# training_step = 33 --- value = -145.2389 --- desired value set for optimization = -1250.0
# training_step = 34 --- value = -151.3566 --- desired value set for optimization = -1250.0
# training_step = 35 --- value = -157.2959 --- desired value set for optimization = -1250.0
# training_step = 36 --- value = -159.0703 --- desired value set for optimization = -1250.0
# training_step = 37 --- value = -159.5364 --- desired value set for optimization = -1250.0
# training_step = 38 --- value = -160.3665 --- desired value set for optimization = -1250.0
# training_step = 39 --- value = -162.0010 --- desired value set for optimization = -1250.0
# training_step = 40 --- value = -164.3287 --- desired value set for optimization = -1250.0
# training_step = 41 --- value = -167.3065 --- desired value set for optimization = -1250.0
# training_step = 42 --- value = -170.8598 --- desired value set for optimization = -1250.0
# training_step = 43 --- value = -172.1185 --- desired value set for optimization = -1250.0
# training_step = 44 --- value = -172.0648 --- desired value set for optimization = -1250.0
# training_step = 45 --- value = -172.3174 --- desired value set for optimization = -1250.0
# training_step = 46 --- value = -172.8494 --- desired value set for optimization = -1250.0
# training_step = 47 --- value = -173.6366 --- desired value set for optimization = -1250.0
# training_step = 48 --- value = -174.6563 --- desired value set for optimization = -1250.0
# training_step = 49 --- value = -175.8884 --- desired value set for optimization = -1250.0
# training_step = 50 --- value = -177.3448 --- desired value set for optimization = -1250.0
# training_step = 51 --- value = -179.0184 --- desired value set for optimization = -1250.0
# training_step = 52 --- value = -180.2775 --- desired value set for optimization = -1250.0
# training_step = 53 --- value = -178.8986 --- desired value set for optimization = -1250.0
# training_step = 54 --- value = -178.0633 --- desired value set for optimization = -1250.0
# training_step = 55 --- value = -177.9382 --- desired value set for optimization = -1250.0
# training_step = 56 --- value = -178.4517 --- desired value set for optimization = -1250.0
# training_step = 57 --- value = -179.5387 --- desired value set for optimization = -1250.0
# training_step = 58 --- value = -179.9420 --- desired value set for optimization = -1250.0
# training_step = 59 --- value = -179.3082 --- desired value set for optimization = -1250.0
# training_step = 60 --- value = -178.9549 --- desired value set for optimization = -1250.0
# training_step = 61 --- value = -178.8568 --- desired value set for optimization = -1250.0
# training_step = 62 --- value = -178.9905 --- desired value set for optimization = -1250.0
# training_step = 63 --- value = -179.3350 --- desired value set for optimization = -1250.0
# training_step = 64 --- value = -179.8711 --- desired value set for optimization = -1250.0
# training_step = 65 --- value = -180.1020 --- desired value set for optimization = -1250.0
# training_step = 66 --- value = -179.6716 --- desired value set for optimization = -1250.0
# training_step = 67 --- value = -179.9302 --- desired value set for optimization = -1250.0
# training_step = 68 --- value = -180.1745 --- desired value set for optimization = -1250.0
# training_step = 69 --- value = -179.9348 --- desired value set for optimization = -1250.0
# training_step = 70 --- value = -179.9449 --- desired value set for optimization = -1250.0
# training_step = 71 --- value = -180.1820 --- desired value set for optimization = -1250.0
# training_step = 72 --- value = -180.0654 --- desired value set for optimization = -1250.0
# training_step = 73 --- value = -180.0511 --- desired value set for optimization = -1250.0
# training_step = 74 --- value = -180.2602 --- desired value set for optimization = -1250.0
# training_step = 75 --- value = -180.1495 --- desired value set for optimization = -1250.0
# training_step = 76 --- value = -180.2796 --- desired value set for optimization = -1250.0
# training_step = 77 --- value = -180.0847 --- desired value set for optimization = -1250.0
# training_step = 78 --- value = -180.2206 --- desired value set for optimization = -1250.0
# training_step = 79 --- value = -180.0909 --- desired value set for optimization = -1250.0
# training_step = 80 --- value = -179.9068 --- desired value set for optimization = -1250.0
# training_step = 81 --- value = -179.9729 --- desired value set for optimization = -1250.0
# training_step = 82 --- value = -180.2659 --- desired value set for optimization = -1250.0
# training_step = 83 --- value = -179.8821 --- desired value set for optimization = -1250.0
# training_step = 84 --- value = -179.7981 --- desired value set for optimization = -1250.0
# training_step = 85 --- value = -180.3933 --- desired value set for optimization = -1250.0
# training_step = 86 --- value = -179.7603 --- desired value set for optimization = -1250.0
# training_step = 87 --- value = -179.3549 --- desired value set for optimization = -1250.0
# training_step = 88 --- value = -179.2238 --- desired value set for optimization = -1250.0
# training_step = 89 --- value = -179.3412 --- desired value set for optimization = -1250.0
# training_step = 90 --- value = -179.6839 --- desired value set for optimization = -1250.0
# training_step = 91 --- value = -180.2307 --- desired value set for optimization = -1250.0
# training_step = 92 --- value = -179.5887 --- desired value set for optimization = -1250.0
# training_step = 93 --- value = -179.1613 --- desired value set for optimization = -1250.0
# training_step = 94 --- value = -179.4597 --- desired value set for optimization = -1250.0
# training_step = 95 --- value = -180.4098 --- desired value set for optimization = -1250.0
# training_step = 96 --- value = -179.5839 --- desired value set for optimization = -1250.0
# training_step = 97 --- value = -179.0069 --- desired value set for optimization = -1250.0
# training_step = 98 --- value = -178.8183 --- desired value set for optimization = -1250.0
# training_step = 99 --- value = -178.8415 --- desired value set for optimization = -1250.0
# training_step = 100 --- value = -179.0008 --- desired value set for optimization = -1250.0
# training_step = 101 --- value = -179.2831 --- desired value set for optimization = -1250.0
# training_step = 102 --- value = -179.6768 --- desired value set for optimization = -1250.0
# training_step = 103 --- value = -180.1711 --- desired value set for optimization = -1250.0
# training_step = 104 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 105 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 106 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 107 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 108 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 109 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 110 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 111 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 112 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 113 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 114 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 115 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 116 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 117 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 118 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 119 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 120 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 121 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 122 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 123 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 124 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 125 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 126 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 127 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 128 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 129 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 130 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 131 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 132 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 133 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 134 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 135 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 136 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 137 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 138 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 139 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 140 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 141 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 142 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 143 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 144 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 145 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 146 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 147 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 148 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 149 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 150 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 151 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 152 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 153 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 154 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 155 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 156 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 157 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 158 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 159 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 160 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 161 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 162 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 163 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 164 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 165 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 166 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 167 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 168 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 169 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 170 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 171 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 172 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 173 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 174 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 175 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 176 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 177 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 178 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 179 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 180 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 181 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 182 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 183 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 184 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 185 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 186 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 187 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 188 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 189 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 190 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 191 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 192 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 193 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 194 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 195 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 196 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 197 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 198 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 199 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 200 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 201 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 202 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 203 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 204 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 205 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 206 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 207 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 208 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 209 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 210 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 211 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 212 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 213 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 214 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 215 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 216 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 217 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 218 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 219 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 220 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 221 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 222 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 223 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 224 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 225 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 226 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 227 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 228 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 229 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 230 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 231 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 232 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 233 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 234 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 235 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 236 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 237 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 238 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 239 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 240 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 241 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 242 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 243 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 244 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 245 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 246 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 247 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 248 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 249 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 250 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 251 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 252 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 253 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 254 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 255 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 256 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 257 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 258 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 259 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 260 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 261 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 262 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 263 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 264 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 265 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 266 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 267 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 268 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 269 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 270 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 271 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 272 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 273 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 274 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 275 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 276 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 277 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 278 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 279 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 280 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 281 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 282 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 283 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 284 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 285 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 286 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 287 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 288 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 289 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 290 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 291 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 292 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 293 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 294 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 295 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 296 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 297 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 298 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 299 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 300 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 301 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 302 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 303 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 304 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 305 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 306 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 307 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 308 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 309 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 310 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 311 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 312 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 313 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 314 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 315 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 316 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 317 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 318 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 319 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 320 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 321 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 322 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 323 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 324 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 325 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 326 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 327 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 328 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 329 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 330 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 331 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 332 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 333 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 334 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 335 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step = 336 --- value = -180.5000 --- desired value set for optimization = -1250.0
# training_step =