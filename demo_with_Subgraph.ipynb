# %% [markdown]
# # Dataless Neural Network for MIS finding in Graphs

# %% [markdown]
# ## 1. Generate a random dense graph using NetworkX
# This will be the graph that we find the MIS of

# %%
import networkx as nx

NUMBER_OF_NODES = 100
NUMBER_OF_EDGES = 600
SEED = 13

G = nx.generators.dense_gnm_random_graph(NUMBER_OF_NODES, NUMBER_OF_EDGES, seed=SEED)

nx.draw(G,with_labels=True)

# %% [markdown]
# ## 2. Generate a neural network to solve your graph's MIS

# %% [markdown]
# ### Perform an optimization using the structure and weights to determine the MIS

# %%
from DNNMIS_SUBGRAPH import DNNMIS_SUBGRAPH

test = DNNMIS_SUBGRAPH(G,{
        "learning_rate": 0.001,
        "selection_criteria": 0.8,
        "max_steps": 1500
    } )
test.solve()
print(test.solution)
# Out:
# Training step: 0, Output: 2747.8916, Desired Output: -5000.0000
# Training step: 1, Output: 2707.0596, Desired Output: -5000.0000
# Training step: 2, Output: 2666.6562, Desired Output: -5000.0000
# Training step: 3, Output: 2626.2891, Desired Output: -5000.0000
# Training step: 4, Output: 2586.9197, Desired Output: -5000.0000
# Training step: 5, Output: 2548.0576, Desired Output: -5000.0000
# Training step: 6, Output: 2509.4487, Desired Output: -5000.0000
# Training step: 7, Output: 2471.4189, Desired Output: -5000.0000
# Training step: 8, Output: 2433.5664, Desired Output: -5000.0000
# Training step: 9, Output: 2396.4392, Desired Output: -5000.0000
# Training step: 10, Output: 2359.8994, Desired Output: -5000.0000
# Training step: 11, Output: 2324.1562, Desired Output: -5000.0000
# Training step: 12, Output: 2288.8552, Desired Output: -5000.0000
# Training step: 13, Output: 2253.8921, Desired Output: -5000.0000
# Training step: 14, Output: 2219.3271, Desired Output: -5000.0000
# Training step: 15, Output: 2185.1636, Desired Output: -5000.0000
# Training step: 16, Output: 2151.5042, Desired Output: -5000.0000
# Training step: 17, Output: 2118.2041, Desired Output: -5000.0000
# Training step: 18, Output: 2085.6460, Desired Output: -5000.0000
# Training step: 19, Output: 2053.5938, Desired Output: -5000.0000
# Training step: 20, Output: 2022.1210, Desired Output: -5000.0000
# Training step: 21, Output: 1990.9824, Desired Output: -5000.0000
# Training step: 22, Output: 1960.1758, Desired Output: -5000.0000
# Training step: 23, Output: 1929.8726, Desired Output: -5000.0000
# Training step: 24, Output: 1900.3740, Desired Output: -5000.0000
# Training step: 25, Output: 1871.1334, Desired Output: -5000.0000
# Training step: 26, Output: 1841.9637, Desired Output: -5000.0000
# Training step: 27, Output: 1813.0457, Desired Output: -5000.0000
# Training step: 28, Output: 1784.3733, Desired Output: -5000.0000
# Training step: 29, Output: 1755.9871, Desired Output: -5000.0000
# Training step: 30, Output: 1727.9729, Desired Output: -5000.0000
# Training step: 31, Output: 1700.2354, Desired Output: -5000.0000
# Training step: 32, Output: 1673.0154, Desired Output: -5000.0000
# Training step: 33, Output: 1646.0312, Desired Output: -5000.0000
# Training step: 34, Output: 1619.3571, Desired Output: -5000.0000
# Training step: 35, Output: 1593.0498, Desired Output: -5000.0000
# Training step: 36, Output: 1567.2314, Desired Output: -5000.0000
# Training step: 37, Output: 1541.9780, Desired Output: -5000.0000
# Training step: 38, Output: 1517.1145, Desired Output: -5000.0000
# Training step: 39, Output: 1492.7686, Desired Output: -5000.0000
# Training step: 40, Output: 1469.1548, Desired Output: -5000.0000
# Training step: 41, Output: 1445.9910, Desired Output: -5000.0000
# Training step: 42, Output: 1423.1162, Desired Output: -5000.0000
# Training step: 43, Output: 1400.8617, Desired Output: -5000.0000
# Training step: 44, Output: 1379.4556, Desired Output: -5000.0000
# Training step: 45, Output: 1358.5900, Desired Output: -5000.0000
# Training step: 46, Output: 1337.8696, Desired Output: -5000.0000
# Training step: 47, Output: 1317.4333, Desired Output: -5000.0000
# Training step: 48, Output: 1297.2316, Desired Output: -5000.0000
# Training step: 49, Output: 1277.1609, Desired Output: -5000.0000
# Training step: 50, Output: 1257.3013, Desired Output: -5000.0000
# Training step: 51, Output: 1237.7496, Desired Output: -5000.0000
# Training step: 52, Output: 1218.6150, Desired Output: -5000.0000
# Training step: 53, Output: 1200.1051, Desired Output: -5000.0000
# Training step: 54, Output: 1182.0129, Desired Output: -5000.0000
# Training step: 55, Output: 1163.9866, Desired Output: -5000.0000
# Training step: 56, Output: 1146.0134, Desired Output: -5000.0000
# Training step: 57, Output: 1128.0881, Desired Output: -5000.0000
# Training step: 58, Output: 1110.4117, Desired Output: -5000.0000
# Training step: 59, Output: 1092.9138, Desired Output: -5000.0000
# Training step: 60, Output: 1075.8301, Desired Output: -5000.0000
# Training step: 61, Output: 1058.8647, Desired Output: -5000.0000
# Training step: 62, Output: 1042.0399, Desired Output: -5000.0000
# Training step: 63, Output: 1025.5054, Desired Output: -5000.0000
# Training step: 64, Output: 1009.1276, Desired Output: -5000.0000
# Training step: 65, Output: 992.9397, Desired Output: -5000.0000
# Training step: 66, Output: 977.1454, Desired Output: -5000.0000
# Training step: 67, Output: 962.1113, Desired Output: -5000.0000
# Training step: 68, Output: 947.4489, Desired Output: -5000.0000
# Training step: 69, Output: 933.1262, Desired Output: -5000.0000
# Training step: 70, Output: 919.0602, Desired Output: -5000.0000
# Training step: 71, Output: 905.2352, Desired Output: -5000.0000
# Training step: 72, Output: 891.6107, Desired Output: -5000.0000
# Training step: 73, Output: 878.1250, Desired Output: -5000.0000
# Training step: 74, Output: 864.6779, Desired Output: -5000.0000
# Training step: 75, Output: 851.4222, Desired Output: -5000.0000
# Training step: 76, Output: 838.4970, Desired Output: -5000.0000
# Training step: 77, Output: 825.8230, Desired Output: -5000.0000
# Training step: 78, Output: 813.2006, Desired Output: -5000.0000
# Training step: 79, Output: 800.8055, Desired Output: -5000.0000
# Training step: 80, Output: 788.6545, Desired Output: -5000.0000
# Training step: 81, Output: 776.5430, Desired Output: -5000.0000
# Training step: 82, Output: 764.5125, Desired Output: -5000.0000
# Training step: 83, Output: 752.6031, Desired Output: -5000.0000
# Training step: 84, Output: 740.8834, Desired Output: -5000.0000
# Training step: 85, Output: 729.3812, Desired Output: -5000.0000
# Training step: 86, Output: 718.0280, Desired Output: -5000.0000
# Training step: 87, Output: 706.7163, Desired Output: -5000.0000
# Training step: 88, Output: 695.4176, Desired Output: -5000.0000
# Training step: 89, Output: 684.2501, Desired Output: -5000.0000
# Training step: 90, Output: 673.1323, Desired Output: -5000.0000
# Training step: 91, Output: 662.0977, Desired Output: -5000.0000
# Training step: 92, Output: 651.2198, Desired Output: -5000.0000
# Training step: 93, Output: 640.6594, Desired Output: -5000.0000
# Training step: 94, Output: 630.2325, Desired Output: -5000.0000
# Training step: 95, Output: 620.0155, Desired Output: -5000.0000
# Training step: 96, Output: 609.8843, Desired Output: -5000.0000
# Training step: 97, Output: 599.9473, Desired Output: -5000.0000
# Training step: 98, Output: 590.0978, Desired Output: -5000.0000
# Training step: 99, Output: 580.3160, Desired Output: -5000.0000
# Training step: 100, Output: 570.8846, Desired Output: -5000.0000
# Training step: 101, Output: 561.7349, Desired Output: -5000.0000
# Training step: 102, Output: 552.7062, Desired Output: -5000.0000
# Training step: 103, Output: 543.9006, Desired Output: -5000.0000
# Training step: 104, Output: 535.3102, Desired Output: -5000.0000
# Training step: 105, Output: 526.8493, Desired Output: -5000.0000
# Training step: 106, Output: 518.4753, Desired Output: -5000.0000
# Training step: 107, Output: 510.2490, Desired Output: -5000.0000
# Training step: 108, Output: 502.2673, Desired Output: -5000.0000
# Training step: 109, Output: 494.4367, Desired Output: -5000.0000
# Training step: 110, Output: 486.6374, Desired Output: -5000.0000
# Training step: 111, Output: 478.8667, Desired Output: -5000.0000
# Training step: 112, Output: 471.1191, Desired Output: -5000.0000
# Training step: 113, Output: 463.4006, Desired Output: -5000.0000
# Training step: 114, Output: 455.9417, Desired Output: -5000.0000
# Training step: 115, Output: 448.6968, Desired Output: -5000.0000
# Training step: 116, Output: 441.7147, Desired Output: -5000.0000
# Training step: 117, Output: 434.7887, Desired Output: -5000.0000
# Training step: 118, Output: 427.8912, Desired Output: -5000.0000
# Training step: 119, Output: 421.0200, Desired Output: -5000.0000
# Training step: 120, Output: 414.1707, Desired Output: -5000.0000
# Training step: 121, Output: 407.3386, Desired Output: -5000.0000
# Training step: 122, Output: 400.5175, Desired Output: -5000.0000
# Training step: 123, Output: 393.7068, Desired Output: -5000.0000
# Training step: 124, Output: 386.9458, Desired Output: -5000.0000
# Training step: 125, Output: 380.2266, Desired Output: -5000.0000
# Training step: 126, Output: 373.5672, Desired Output: -5000.0000
# Training step: 127, Output: 366.9928, Desired Output: -5000.0000
# Training step: 128, Output: 360.4235, Desired Output: -5000.0000
# Training step: 129, Output: 353.9399, Desired Output: -5000.0000
# Training step: 130, Output: 347.6743, Desired Output: -5000.0000
# Training step: 131, Output: 341.4241, Desired Output: -5000.0000
# Training step: 132, Output: 335.1826, Desired Output: -5000.0000
# Training step: 133, Output: 328.9782, Desired Output: -5000.0000
# Training step: 134, Output: 322.9548, Desired Output: -5000.0000
# Training step: 135, Output: 316.9385, Desired Output: -5000.0000
# Training step: 136, Output: 310.9686, Desired Output: -5000.0000
# Training step: 137, Output: 305.2892, Desired Output: -5000.0000
# Training step: 138, Output: 299.9710, Desired Output: -5000.0000
# Training step: 139, Output: 294.6890, Desired Output: -5000.0000
# Training step: 140, Output: 289.4257, Desired Output: -5000.0000
# Training step: 141, Output: 284.2412, Desired Output: -5000.0000
# Training step: 142, Output: 279.0940, Desired Output: -5000.0000
# Training step: 143, Output: 273.9893, Desired Output: -5000.0000
# Training step: 144, Output: 268.9879, Desired Output: -5000.0000
# Training step: 145, Output: 264.0770, Desired Output: -5000.0000
# Training step: 146, Output: 259.3771, Desired Output: -5000.0000
# Training step: 147, Output: 254.6921, Desired Output: -5000.0000
# Training step: 148, Output: 250.0232, Desired Output: -5000.0000
# Training step: 149, Output: 245.4544, Desired Output: -5000.0000
# Training step: 150, Output: 241.1053, Desired Output: -5000.0000
# Training step: 151, Output: 236.9009, Desired Output: -5000.0000
# Training step: 152, Output: 232.7150, Desired Output: -5000.0000
# Training step: 153, Output: 228.5505, Desired Output: -5000.0000
# Training step: 154, Output: 224.5257, Desired Output: -5000.0000
# Training step: 155, Output: 220.5832, Desired Output: -5000.0000
# Training step: 156, Output: 216.7493, Desired Output: -5000.0000
# Training step: 157, Output: 212.8925, Desired Output: -5000.0000
# Training step: 158, Output: 209.0742, Desired Output: -5000.0000
# Training step: 159, Output: 205.4044, Desired Output: -5000.0000
# Training step: 160, Output: 201.8407, Desired Output: -5000.0000
# Training step: 161, Output: 198.4164, Desired Output: -5000.0000
# Training step: 162, Output: 195.0036, Desired Output: -5000.0000
# Training step: 163, Output: 191.6008, Desired Output: -5000.0000
# Training step: 164, Output: 188.2327, Desired Output: -5000.0000
# Training step: 165, Output: 184.9842, Desired Output: -5000.0000
# Training step: 166, Output: 181.7384, Desired Output: -5000.0000
# Training step: 167, Output: 178.4947, Desired Output: -5000.0000
# Training step: 168, Output: 175.2785, Desired Output: -5000.0000
# Training step: 169, Output: 172.1391, Desired Output: -5000.0000
# Training step: 170, Output: 169.0132, Desired Output: -5000.0000
# Training step: 171, Output: 166.0055, Desired Output: -5000.0000
# Training step: 172, Output: 163.0045, Desired Output: -5000.0000
# Training step: 173, Output: 160.1057, Desired Output: -5000.0000
# Training step: 174, Output: 157.2864, Desired Output: -5000.0000
# Training step: 175, Output: 154.5400, Desired Output: -5000.0000
# Training step: 176, Output: 151.8754, Desired Output: -5000.0000
# Training step: 177, Output: 149.2205, Desired Output: -5000.0000
# Training step: 178, Output: 146.5686, Desired Output: -5000.0000
# Training step: 179, Output: 143.9831, Desired Output: -5000.0000
# Training step: 180, Output: 141.6787, Desired Output: -5000.0000
# Training step: 181, Output: 139.4410, Desired Output: -5000.0000
# Training step: 182, Output: 137.2161, Desired Output: -5000.0000
# Training step: 183, Output: 135.0033, Desired Output: -5000.0000
# Training step: 184, Output: 132.8012, Desired Output: -5000.0000
# Training step: 185, Output: 130.6140, Desired Output: -5000.0000
# Training step: 186, Output: 128.6017, Desired Output: -5000.0000
# Training step: 187, Output: 126.4149, Desired Output: -5000.0000
# Training step: 188, Output: 124.2659, Desired Output: -5000.0000
# Training step: 189, Output: 122.2691, Desired Output: -5000.0000
# Training step: 190, Output: 120.2893, Desired Output: -5000.0000
# Training step: 191, Output: 118.3190, Desired Output: -5000.0000
# Training step: 192, Output: 116.3483, Desired Output: -5000.0000
# Training step: 193, Output: 114.3750, Desired Output: -5000.0000
# Training step: 194, Output: 112.4004, Desired Output: -5000.0000
# Training step: 195, Output: 110.4218, Desired Output: -5000.0000
# Training step: 196, Output: 108.4442, Desired Output: -5000.0000
# Training step: 197, Output: 106.6075, Desired Output: -5000.0000
# Training step: 198, Output: 104.7766, Desired Output: -5000.0000
# Training step: 199, Output: 103.0290, Desired Output: -5000.0000
# Training step: 200, Output: 101.2547, Desired Output: -5000.0000
# Training step: 201, Output: 99.4535, Desired Output: -5000.0000
# Training step: 202, Output: 97.6553, Desired Output: -5000.0000
# Training step: 203, Output: 95.8392, Desired Output: -5000.0000
# Training step: 204, Output: 94.0023, Desired Output: -5000.0000
# Training step: 205, Output: 92.1723, Desired Output: -5000.0000
# Training step: 206, Output: 90.4244, Desired Output: -5000.0000
# Training step: 207, Output: 88.7246, Desired Output: -5000.0000
# Training step: 208, Output: 87.0198, Desired Output: -5000.0000
# Training step: 209, Output: 85.3818, Desired Output: -5000.0000
# Training step: 210, Output: 83.7688, Desired Output: -5000.0000
# Training step: 211, Output: 82.1522, Desired Output: -5000.0000
# Training step: 212, Output: 80.5361, Desired Output: -5000.0000
# Training step: 213, Output: 78.9930, Desired Output: -5000.0000
# Training step: 214, Output: 77.4558, Desired Output: -5000.0000
# Training step: 215, Output: 75.9505, Desired Output: -5000.0000
# Training step: 216, Output: 74.5387, Desired Output: -5000.0000
# Training step: 217, Output: 73.3355, Desired Output: -5000.0000
# Training step: 218, Output: 72.0423, Desired Output: -5000.0000
# Training step: 219, Output: 70.7788, Desired Output: -5000.0000
# Training step: 220, Output: 69.4989, Desired Output: -5000.0000
# Training step: 221, Output: 68.3360, Desired Output: -5000.0000
# Training step: 222, Output: 67.2119, Desired Output: -5000.0000
# Training step: 223, Output: 66.1012, Desired Output: -5000.0000
# Training step: 224, Output: 64.9882, Desired Output: -5000.0000
# Training step: 225, Output: 63.8915, Desired Output: -5000.0000
# Training step: 226, Output: 62.7927, Desired Output: -5000.0000
# Training step: 227, Output: 61.7588, Desired Output: -5000.0000
# Training step: 228, Output: 60.7145, Desired Output: -5000.0000
# Training step: 229, Output: 59.6733, Desired Output: -5000.0000
# Training step: 230, Output: 58.7356, Desired Output: -5000.0000
# Training step: 231, Output: 57.7391, Desired Output: -5000.0000
# Training step: 232, Output: 56.8298, Desired Output: -5000.0000
# Training step: 233, Output: 55.8318, Desired Output: -5000.0000
# Training step: 234, Output: 54.8794, Desired Output: -5000.0000
# Training step: 235, Output: 54.1274, Desired Output: -5000.0000
# Training step: 236, Output: 53.2334, Desired Output: -5000.0000
# Training step: 237, Output: 52.2146, Desired Output: -5000.0000
# Training step: 238, Output: 51.2594, Desired Output: -5000.0000
# Training step: 239, Output: 50.4291, Desired Output: -5000.0000
# Training step: 240, Output: 49.5860, Desired Output: -5000.0000
# Training step: 241, Output: 48.7454, Desired Output: -5000.0000
# Training step: 242, Output: 47.8886, Desired Output: -5000.0000
# Training step: 243, Output: 47.0448, Desired Output: -5000.0000
# Training step: 244, Output: 46.1578, Desired Output: -5000.0000
# Training step: 245, Output: 45.2881, Desired Output: -5000.0000
# Training step: 246, Output: 44.4231, Desired Output: -5000.0000
# Training step: 247, Output: 43.5284, Desired Output: -5000.0000
# Training step: 248, Output: 42.6339, Desired Output: -5000.0000
# Training step: 249, Output: 41.7340, Desired Output: -5000.0000
# Training step: 250, Output: 40.8326, Desired Output: -5000.0000
# Training step: 251, Output: 39.9261, Desired Output: -5000.0000
# Training step: 252, Output: 39.0236, Desired Output: -5000.0000
# Training step: 253, Output: 38.0983, Desired Output: -5000.0000
# Training step: 254, Output: 37.1701, Desired Output: -5000.0000
# Training step: 255, Output: 36.2731, Desired Output: -5000.0000
# Training step: 256, Output: 35.2987, Desired Output: -5000.0000
# Training step: 257, Output: 34.4317, Desired Output: -5000.0000
# Training step: 258, Output: 33.5275, Desired Output: -5000.0000
# Training step: 259, Output: 32.5839, Desired Output: -5000.0000
# Training step: 260, Output: 31.7482, Desired Output: -5000.0000
# Training step: 261, Output: 30.9019, Desired Output: -5000.0000
# Training step: 262, Output: 30.0444, Desired Output: -5000.0000
# Training step: 263, Output: 29.1671, Desired Output: -5000.0000
# Training step: 264, Output: 28.2798, Desired Output: -5000.0000
# Training step: 265, Output: 27.3995, Desired Output: -5000.0000
# Training step: 266, Output: 26.4777, Desired Output: -5000.0000
# Training step: 267, Output: 25.5968, Desired Output: -5000.0000
# Training step: 268, Output: 24.7086, Desired Output: -5000.0000
# Training step: 269, Output: 23.7586, Desired Output: -5000.0000
# Training step: 270, Output: 22.8253, Desired Output: -5000.0000
# Training step: 271, Output: 21.9004, Desired Output: -5000.0000
# Training step: 272, Output: 20.9945, Desired Output: -5000.0000
# Training step: 273, Output: 20.0815, Desired Output: -5000.0000
# Training step: 274, Output: 19.1249, Desired Output: -5000.0000
# Training step: 275, Output: 18.1911, Desired Output: -5000.0000
# Training step: 276, Output: 17.2522, Desired Output: -5000.0000
# Training step: 277, Output: 16.3399, Desired Output: -5000.0000
# Training step: 278, Output: 15.3959, Desired Output: -5000.0000
# Training step: 279, Output: 14.5302, Desired Output: -5000.0000
# Training step: 280, Output: 13.7396, Desired Output: -5000.0000
# Training step: 281, Output: 12.9444, Desired Output: -5000.0000
# Training step: 282, Output: 12.1228, Desired Output: -5000.0000
# Training step: 283, Output: 11.3379, Desired Output: -5000.0000
# Training step: 284, Output: 10.5064, Desired Output: -5000.0000
# Training step: 285, Output: 9.7198, Desired Output: -5000.0000
# Training step: 286, Output: 8.9367, Desired Output: -5000.0000
# Training step: 287, Output: 8.1338, Desired Output: -5000.0000
# Training step: 288, Output: 7.3592, Desired Output: -5000.0000
# Training step: 289, Output: 6.6525, Desired Output: -5000.0000
# Training step: 290, Output: 5.9448, Desired Output: -5000.0000
# Training step: 291, Output: 5.2397, Desired Output: -5000.0000
# Training step: 292, Output: 4.5631, Desired Output: -5000.0000
# Training step: 293, Output: 3.8606, Desired Output: -5000.0000
# Training step: 294, Output: 3.2946, Desired Output: -5000.0000
# Training step: 295, Output: 2.7642, Desired Output: -5000.0000
# Training step: 296, Output: 2.2647, Desired Output: -5000.0000
# Training step: 297, Output: 1.7583, Desired Output: -5000.0000
# Training step: 298, Output: 1.2338, Desired Output: -5000.0000
# Training step: 299, Output: 0.6961, Desired Output: -5000.0000
# Training step: 300, Output: 0.1888, Desired Output: -5000.0000
# Training step: 301, Output: -0.3024, Desired Output: -5000.0000
# Training step: 302, Output: -0.8144, Desired Output: -5000.0000
# Training step: 303, Output: -1.2633, Desired Output: -5000.0000
# Training step: 304, Output: -1.7064, Desired Output: -5000.0000
# Training step: 305, Output: -2.1496, Desired Output: -5000.0000
# Training step: 306, Output: -2.6033, Desired Output: -5000.0000
# Training step: 307, Output: -3.0733, Desired Output: -5000.0000
# Training step: 308, Output: -3.5224, Desired Output: -5000.0000
# Training step: 309, Output: -3.9992, Desired Output: -5000.0000
# Training step: 310, Output: -4.3902, Desired Output: -5000.0000
# Training step: 311, Output: -4.7689, Desired Output: -5000.0000
# Training step: 312, Output: -5.1228, Desired Output: -5000.0000
# Training step: 313, Output: -5.4482, Desired Output: -5000.0000
# Training step: 314, Output: -5.7901, Desired Output: -5000.0000
# Training step: 315, Output: -6.0423, Desired Output: -5000.0000
# Training step: 316, Output: -6.2780, Desired Output: -5000.0000
# Training step: 317, Output: -6.5366, Desired Output: -5000.0000
# Training step: 318, Output: -6.7932, Desired Output: -5000.0000
# Training step: 319, Output: -7.0205, Desired Output: -5000.0000
# Training step: 320, Output: -7.2595, Desired Output: -5000.0000
# Training step: 321, Output: -7.4836, Desired Output: -5000.0000
# Training step: 322, Output: -7.6020, Desired Output: -5000.0000
# Training step: 323, Output: -7.7370, Desired Output: -5000.0000
# Training step: 324, Output: -7.8946, Desired Output: -5000.0000
# Training step: 325, Output: -8.0078, Desired Output: -5000.0000
# Training step: 326, Output: -8.1743, Desired Output: -5000.0000
# Training step: 327, Output: -8.3427, Desired Output: -5000.0000
# Training step: 328, Output: -8.4922, Desired Output: -5000.0000
# Training step: 329, Output: -8.6669, Desired Output: -5000.0000
# Training step: 330, Output: -8.8258, Desired Output: -5000.0000
# Training step: 331, Output: -8.9745, Desired Output: -5000.0000
# Training step: 332, Output: -9.1534, Desired Output: -5000.0000
# Training step: 333, Output: -9.3246, Desired Output: -5000.0000
# Training step: 334, Output: -9.4972, Desired Output: -5000.0000
# Training step: 335, Output: -9.6686, Desired Output: -5000.0000
# Training step: 336, Output: -9.8444, Desired Output: -5000.0000
# Training step: 337, Output: -10.0321, Desired Output: -5000.0000
# Training step: 338, Output: -10.2219, Desired Output: -5000.0000
# Training step: 339, Output: -10.3584, Desired Output: -5000.0000
# Training step: 340, Output: -10.5801, Desired Output: -5000.0000
# Training step: 341, Output: -10.7610, Desired Output: -5000.0000
# Training step: 342, Output: -10.9468, Desired Output: -5000.0000
# Training step: 343, Output: -11.1394, Desired Output: -5000.0000
# Training step: 344, Output: -11.3437, Desired Output: -5000.0000
# Training step: 345, Output: -11.5232, Desired Output: -5000.0000
# Training step: 346, Output: -11.7304, Desired Output: -5000.0000
# Training step: 347, Output: -11.9271, Desired Output: -5000.0000
# Training step: 348, Output: -12.0984, Desired Output: -5000.0000
# Training step: 349, Output: -12.3190, Desired Output: -5000.0000
# Training step: 350, Output: -12.5084, Desired Output: -5000.0000
# Training step: 351, Output: -12.7239, Desired Output: -5000.0000
# Training step: 352, Output: -12.9288, Desired Output: -5000.0000
# Training step: 353, Output: -13.1270, Desired Output: -5000.0000
# Training step: 354, Output: -13.3517, Desired Output: -5000.0000
# Training step: 355, Output: -13.5638, Desired Output: -5000.0000
# Training step: 356, Output: -13.7706, Desired Output: -5000.0000
# Training step: 357, Output: -13.9865, Desired Output: -5000.0000
# Training step: 358, Output: -14.2316, Desired Output: -5000.0000
# Training step: 359, Output: -14.4634, Desired Output: -5000.0000
# Training step: 360, Output: -14.6845, Desired Output: -5000.0000
# Training step: 361, Output: -14.9121, Desired Output: -5000.0000
# Training step: 362, Output: -15.1413, Desired Output: -5000.0000
# Training step: 363, Output: -15.3752, Desired Output: -5000.0000
# Training step: 364, Output: -15.5591, Desired Output: -5000.0000
# Training step: 365, Output: -15.8068, Desired Output: -5000.0000
# Training step: 366, Output: -16.0327, Desired Output: -5000.0000
# Training step: 367, Output: -16.2249, Desired Output: -5000.0000
# Training step: 368, Output: -16.4637, Desired Output: -5000.0000
# Training step: 369, Output: -16.6829, Desired Output: -5000.0000
# Training step: 370, Output: -16.8828, Desired Output: -5000.0000
# Training step: 371, Output: -17.0990, Desired Output: -5000.0000
# Training step: 372, Output: -17.2639, Desired Output: -5000.0000
# Training step: 373, Output: -17.4356, Desired Output: -5000.0000
# Training step: 374, Output: -17.6011, Desired Output: -5000.0000
# Training step: 375, Output: -17.8053, Desired Output: -5000.0000
# Training step: 376, Output: -17.9822, Desired Output: -5000.0000
# Training step: 377, Output: -18.1641, Desired Output: -5000.0000
# Training step: 378, Output: -18.3560, Desired Output: -5000.0000
# Training step: 379, Output: -18.5558, Desired Output: -5000.0000
# Training step: 380, Output: -18.7194, Desired Output: -5000.0000
# Training step: 381, Output: -18.9587, Desired Output: -5000.0000
# Training step: 382, Output: -19.1548, Desired Output: -5000.0000
# Training step: 383, Output: -19.3373, Desired Output: -5000.0000
# Training step: 384, Output: -19.5517, Desired Output: -5000.0000
# Training step: 385, Output: -19.7536, Desired Output: -5000.0000
# Training step: 386, Output: -19.9766, Desired Output: -5000.0000
# Training step: 387, Output: -20.0478, Desired Output: -5000.0000
# Training step: 388, Output: -20.2187, Desired Output: -5000.0000
# Training step: 389, Output: -20.4630, Desired Output: -5000.0000
# Training step: 390, Output: -20.6274, Desired Output: -5000.0000
# Training step: 391, Output: -20.7792, Desired Output: -5000.0000
# Training step: 392, Output: -20.9362, Desired Output: -5000.0000
# Training step: 393, Output: -21.0944, Desired Output: -5000.0000
# Training step: 394, Output: -21.2794, Desired Output: -5000.0000
# Training step: 395, Output: -21.4374, Desired Output: -5000.0000
# Training step: 396, Output: -21.5584, Desired Output: -5000.0000
# Training step: 397, Output: -21.6830, Desired Output: -5000.0000
# Training step: 398, Output: -21.8231, Desired Output: -5000.0000
# Training step: 399, Output: -21.9271, Desired Output: -5000.0000
# Training step: 400, Output: -22.0684, Desired Output: -5000.0000
# Training step: 401, Output: -22.2018, Desired Output: -5000.0000
# Training step: 402, Output: -22.2881, Desired Output: -5000.0000
# Training step: 403, Output: -22.4105, Desired Output: -5000.0000
# Training step: 404, Output: -22.5640, Desired Output: -5000.0000
# Training step: 405, Output: -22.7165, Desired Output: -5000.0000
# Training step: 406, Output: -22.8295, Desired Output: -5000.0000
# Training step: 407, Output: -22.9937, Desired Output: -5000.0000
# Training step: 408, Output: -23.1316, Desired Output: -5000.0000
# Training step: 409, Output: -23.2737, Desired Output: -5000.0000
# Training step: 410, Output: -23.3989, Desired Output: -5000.0000
# Training step: 411, Output: -23.5074, Desired Output: -5000.0000
# Training step: 412, Output: -23.6547, Desired Output: -5000.0000
# Training step: 413, Output: -23.7099, Desired Output: -5000.0000
# Training step: 414, Output: -23.7472, Desired Output: -5000.0000
# Training step: 415, Output: -23.8232, Desired Output: -5000.0000
# Training step: 416, Output: -23.9219, Desired Output: -5000.0000
# Training step: 417, Output: -24.0205, Desired Output: -5000.0000
# Training step: 418, Output: -24.1422, Desired Output: -5000.0000
# Training step: 419, Output: -24.3034, Desired Output: -5000.0000
# Training step: 420, Output: -24.4329, Desired Output: -5000.0000
# Training step: 421, Output: -24.5882, Desired Output: -5000.0000
# Training step: 422, Output: -24.6542, Desired Output: -5000.0000
# Training step: 423, Output: -24.7434, Desired Output: -5000.0000
# Training step: 424, Output: -24.8621, Desired Output: -5000.0000
# Training step: 425, Output: -24.9603, Desired Output: -5000.0000
# Training step: 426, Output: -25.0853, Desired Output: -5000.0000
# Training step: 427, Output: -25.1271, Desired Output: -5000.0000
# Training step: 428, Output: -25.2626, Desired Output: -5000.0000
# Training step: 429, Output: -25.3987, Desired Output: -5000.0000
# Training step: 430, Output: -25.5092, Desired Output: -5000.0000
# Training step: 431, Output: -25.6153, Desired Output: -5000.0000
# Training step: 432, Output: -25.7379, Desired Output: -5000.0000
# Training step: 433, Output: -25.8630, Desired Output: -5000.0000
# Training step: 434, Output: -25.9592, Desired Output: -5000.0000
# Training step: 435, Output: -26.0449, Desired Output: -5000.0000
# Training step: 436, Output: -26.1729, Desired Output: -5000.0000
# Training step: 437, Output: -26.3026, Desired Output: -5000.0000
# Training step: 438, Output: -26.3847, Desired Output: -5000.0000
# Training step: 439, Output: -26.4839, Desired Output: -5000.0000
# Training step: 440, Output: -26.5998, Desired Output: -5000.0000
# Training step: 441, Output: -26.6634, Desired Output: -5000.0000
# Training step: 442, Output: -26.8066, Desired Output: -5000.0000
# Training step: 443, Output: -26.9004, Desired Output: -5000.0000
# Training step: 444, Output: -26.9815, Desired Output: -5000.0000
# Training step: 445, Output: -27.0802, Desired Output: -5000.0000
# Training step: 446, Output: -27.2009, Desired Output: -5000.0000
# Training step: 447, Output: -27.3264, Desired Output: -5000.0000
# Training step: 448, Output: -27.4095, Desired Output: -5000.0000
# Training step: 449, Output: -27.5049, Desired Output: -5000.0000
# Training step: 450, Output: -27.6203, Desired Output: -5000.0000
# Training step: 451, Output: -27.7217, Desired Output: -5000.0000
# Training step: 452, Output: -27.8576, Desired Output: -5000.0000
# Training step: 453, Output: -27.9721, Desired Output: -5000.0000
# Training step: 454, Output: -28.0887, Desired Output: -5000.0000
# Training step: 455, Output: -28.1489, Desired Output: -5000.0000
# Training step: 456, Output: -28.2816, Desired Output: -5000.0000
# Training step: 457, Output: -28.3914, Desired Output: -5000.0000
# Training step: 458, Output: -28.5530, Desired Output: -5000.0000
# Training step: 459, Output: -28.6307, Desired Output: -5000.0000
# Training step: 460, Output: -28.7488, Desired Output: -5000.0000
# Training step: 461, Output: -28.8371, Desired Output: -5000.0000
# Training step: 462, Output: -28.9343, Desired Output: -5000.0000
# Training step: 463, Output: -29.0593, Desired Output: -5000.0000
# Training step: 464, Output: -29.1767, Desired Output: -5000.0000
# Training step: 465, Output: -29.3132, Desired Output: -5000.0000
# Training step: 466, Output: -29.4483, Desired Output: -5000.0000
# Training step: 467, Output: -29.5589, Desired Output: -5000.0000
# Training step: 468, Output: -29.6561, Desired Output: -5000.0000
# Training step: 469, Output: -29.7644, Desired Output: -5000.0000
# Training step: 470, Output: -29.9022, Desired Output: -5000.0000
# Training step: 471, Output: -30.0284, Desired Output: -5000.0000
# Training step: 472, Output: -30.1411, Desired Output: -5000.0000
# Training step: 473, Output: -30.2399, Desired Output: -5000.0000
# Training step: 474, Output: -30.3470, Desired Output: -5000.0000
# Training step: 475, Output: -30.4737, Desired Output: -5000.0000
# Training step: 476, Output: -30.5346, Desired Output: -5000.0000
# Training step: 477, Output: -30.6475, Desired Output: -5000.0000
# Training step: 478, Output: -30.8103, Desired Output: -5000.0000
# Training step: 479, Output: -30.9168, Desired Output: -5000.0000
# Training step: 480, Output: -31.0482, Desired Output: -5000.0000
# Training step: 481, Output: -31.1318, Desired Output: -5000.0000
# Training step: 482, Output: -31.2646, Desired Output: -5000.0000
# Training step: 483, Output: -31.4231, Desired Output: -5000.0000
# Training step: 484, Output: -31.5525, Desired Output: -5000.0000
# Training step: 485, Output: -31.6915, Desired Output: -5000.0000
# Training step: 486, Output: -31.6835, Desired Output: -5000.0000
# Training step: 487, Output: -31.8210, Desired Output: -5000.0000
# Training step: 488, Output: -31.8653, Desired Output: -5000.0000
# Training step: 489, Output: -31.9139, Desired Output: -5000.0000
# Training step: 490, Output: -31.9913, Desired Output: -5000.0000
# Training step: 491, Output: -32.0519, Desired Output: -5000.0000
# Training step: 492, Output: -32.1413, Desired Output: -5000.0000
# Training step: 493, Output: -32.1227, Desired Output: -5000.0000
# Training step: 494, Output: -32.1979, Desired Output: -5000.0000
# Training step: 495, Output: -32.2874, Desired Output: -5000.0000
# Training step: 496, Output: -32.3417, Desired Output: -5000.0000
# Training step: 497, Output: -32.4031, Desired Output: -5000.0000
# Training step: 498, Output: -32.4492, Desired Output: -5000.0000
# Training step: 499, Output: -32.4906, Desired Output: -5000.0000
# Training step: 500, Output: -32.5433, Desired Output: -5000.0000
# Training step: 501, Output: -32.6304, Desired Output: -5000.0000
# Training step: 502, Output: -32.6855, Desired Output: -5000.0000
# Training step: 503, Output: -32.7360, Desired Output: -5000.0000
# Training step: 504, Output: -32.8215, Desired Output: -5000.0000
# Training step: 505, Output: -32.8340, Desired Output: -5000.0000
# Training step: 506, Output: -32.8814, Desired Output: -5000.0000
# Training step: 507, Output: -32.9505, Desired Output: -5000.0000
# Training step: 508, Output: -32.9891, Desired Output: -5000.0000
# Training step: 509, Output: -33.0536, Desired Output: -5000.0000
# Training step: 510, Output: -33.0845, Desired Output: -5000.0000
# Training step: 511, Output: -33.1596, Desired Output: -5000.0000
# Training step: 512, Output: -33.2233, Desired Output: -5000.0000
# Training step: 513, Output: -33.2662, Desired Output: -5000.0000
# Training step: 514, Output: -33.3423, Desired Output: -5000.0000
# Training step: 515, Output: -33.4234, Desired Output: -5000.0000
# Training step: 516, Output: -33.4756, Desired Output: -5000.0000
# Training step: 517, Output: -33.5432, Desired Output: -5000.0000
# Training step: 518, Output: -33.6052, Desired Output: -5000.0000
# Training step: 519, Output: -33.6254, Desired Output: -5000.0000
# Training step: 520, Output: -33.7011, Desired Output: -5000.0000
# Training step: 521, Output: -33.8036, Desired Output: -5000.0000
# Training step: 522, Output: -33.8715, Desired Output: -5000.0000
# Training step: 523, Output: -33.9180, Desired Output: -5000.0000
# Training step: 524, Output: -33.9791, Desired Output: -5000.0000
# Training step: 525, Output: -34.0471, Desired Output: -5000.0000
# Training step: 526, Output: -34.0736, Desired Output: -5000.0000
# Training step: 527, Output: -34.1147, Desired Output: -5000.0000
# Training step: 528, Output: -34.1616, Desired Output: -5000.0000
# Training step: 529, Output: -34.2246, Desired Output: -5000.0000
# Training step: 530, Output: -34.2840, Desired Output: -5000.0000
# Training step: 531, Output: -34.3773, Desired Output: -5000.0000
# Training step: 532, Output: -34.4559, Desired Output: -5000.0000
# Training step: 533, Output: -34.4485, Desired Output: -5000.0000
# Training step: 534, Output: -34.5738, Desired Output: -5000.0000
# Training step: 535, Output: -34.6620, Desired Output: -5000.0000
# Training step: 536, Output: -34.6810, Desired Output: -5000.0000
# Training step: 537, Output: -34.7317, Desired Output: -5000.0000
# Training step: 538, Output: -34.7915, Desired Output: -5000.0000
# Training step: 539, Output: -34.8552, Desired Output: -5000.0000
# Training step: 540, Output: -34.9232, Desired Output: -5000.0000
# Training step: 541, Output: -34.9682, Desired Output: -5000.0000
# Training step: 542, Output: -35.0518, Desired Output: -5000.0000
# Training step: 543, Output: -35.0693, Desired Output: -5000.0000
# Training step: 544, Output: -35.0955, Desired Output: -5000.0000
# Training step: 545, Output: -35.1932, Desired Output: -5000.0000
# Training step: 546, Output: -35.2618, Desired Output: -5000.0000
# Training step: 547, Output: -35.3359, Desired Output: -5000.0000
# Training step: 548, Output: -35.3821, Desired Output: -5000.0000
# Training step: 549, Output: -35.4227, Desired Output: -5000.0000
# Training step: 550, Output: -35.4502, Desired Output: -5000.0000
# Training step: 551, Output: -35.5588, Desired Output: -5000.0000
# Training step: 552, Output: -35.6265, Desired Output: -5000.0000
# Training step: 553, Output: -35.6781, Desired Output: -5000.0000
# Training step: 554, Output: -35.7375, Desired Output: -5000.0000
# Training step: 555, Output: -35.7774, Desired Output: -5000.0000
# Training step: 556, Output: -35.8377, Desired Output: -5000.0000
# Training step: 557, Output: -35.8993, Desired Output: -5000.0000
# Training step: 558, Output: -35.9527, Desired Output: -5000.0000
# Training step: 559, Output: -36.0173, Desired Output: -5000.0000
# Training step: 560, Output: -36.0741, Desired Output: -5000.0000
# Training step: 561, Output: -36.1435, Desired Output: -5000.0000
# Training step: 562, Output: -36.2064, Desired Output: -5000.0000
# Training step: 563, Output: -36.2704, Desired Output: -5000.0000
# Training step: 564, Output: -36.3147, Desired Output: -5000.0000
# Training step: 565, Output: -36.3902, Desired Output: -5000.0000
# Training step: 566, Output: -36.4148, Desired Output: -5000.0000
# Training step: 567, Output: -36.4337, Desired Output: -5000.0000
# Training step: 568, Output: -36.4878, Desired Output: -5000.0000
# Training step: 569, Output: -36.5288, Desired Output: -5000.0000
# Training step: 570, Output: -36.5816, Desired Output: -5000.0000
# Training step: 571, Output: -36.6319, Desired Output: -5000.0000
# Training step: 572, Output: -36.7020, Desired Output: -5000.0000
# Training step: 573, Output: -36.7386, Desired Output: -5000.0000
# Training step: 574, Output: -36.8119, Desired Output: -5000.0000
# Training step: 575, Output: -36.9150, Desired Output: -5000.0000
# Training step: 576, Output: -36.9300, Desired Output: -5000.0000
# Training step: 577, Output: -37.0095, Desired Output: -5000.0000
# Training step: 578, Output: -37.0656, Desired Output: -5000.0000
# Training step: 579, Output: -37.0890, Desired Output: -5000.0000
# Training step: 580, Output: -37.1522, Desired Output: -5000.0000
# Training step: 581, Output: -37.2353, Desired Output: -5000.0000
# Training step: 582, Output: -37.2849, Desired Output: -5000.0000
# Training step: 583, Output: -37.3240, Desired Output: -5000.0000
# Training step: 584, Output: -37.3960, Desired Output: -5000.0000
# Training step: 585, Output: -37.4750, Desired Output: -5000.0000
# Training step: 586, Output: -37.5089, Desired Output: -5000.0000
# Training step: 587, Output: -37.5639, Desired Output: -5000.0000
# Training step: 588, Output: -37.6115, Desired Output: -5000.0000
# Training step: 589, Output: -37.6822, Desired Output: -5000.0000
# Training step: 590, Output: -37.7559, Desired Output: -5000.0000
# Training step: 591, Output: -37.8301, Desired Output: -5000.0000
# Training step: 592, Output: -37.8535, Desired Output: -5000.0000
# Training step: 593, Output: -37.9254, Desired Output: -5000.0000
# Training step: 594, Output: -38.0167, Desired Output: -5000.0000
# Training step: 595, Output: -38.0450, Desired Output: -5000.0000
# Training step: 596, Output: -38.0680, Desired Output: -5000.0000
# Training step: 597, Output: -38.1422, Desired Output: -5000.0000
# Training step: 598, Output: -38.1703, Desired Output: -5000.0000
# Training step: 599, Output: -38.2159, Desired Output: -5000.0000
# Training step: 600, Output: -38.2920, Desired Output: -5000.0000
# Training step: 601, Output: -38.3375, Desired Output: -5000.0000
# Training step: 602, Output: -38.4526, Desired Output: -5000.0000
# Training step: 603, Output: -38.4992, Desired Output: -5000.0000
# Training step: 604, Output: -38.5576, Desired Output: -5000.0000
# Training step: 605, Output: -38.6316, Desired Output: -5000.0000
# Training step: 606, Output: -38.6654, Desired Output: -5000.0000
# Training step: 607, Output: -38.7442, Desired Output: -5000.0000
# Training step: 608, Output: -38.7996, Desired Output: -5000.0000
# Training step: 609, Output: -38.8462, Desired Output: -5000.0000
# Training step: 610, Output: -38.8822, Desired Output: -5000.0000
# Training step: 611, Output: -38.9247, Desired Output: -5000.0000
# Training step: 612, Output: -39.0136, Desired Output: -5000.0000
# Training step: 613, Output: -39.0848, Desired Output: -5000.0000
# Training step: 614, Output: -39.1221, Desired Output: -5000.0000
# Training step: 615, Output: -39.2004, Desired Output: -5000.0000
# Training step: 616, Output: -39.2320, Desired Output: -5000.0000
# Training step: 617, Output: -39.3112, Desired Output: -5000.0000
# Training step: 618, Output: -39.3817, Desired Output: -5000.0000
# Training step: 619, Output: -39.4090, Desired Output: -5000.0000
# Training step: 620, Output: -39.4624, Desired Output: -5000.0000
# Training step: 621, Output: -39.5325, Desired Output: -5000.0000
# Training step: 622, Output: -39.5956, Desired Output: -5000.0000
# Training step: 623, Output: -39.6350, Desired Output: -5000.0000
# Training step: 624, Output: -39.7298, Desired Output: -5000.0000
# Training step: 625, Output: -39.7971, Desired Output: -5000.0000
# Training step: 626, Output: -39.7960, Desired Output: -5000.0000
# Training step: 627, Output: -39.8532, Desired Output: -5000.0000
# Training step: 628, Output: -39.9560, Desired Output: -5000.0000
# Training step: 629, Output: -40.0028, Desired Output: -5000.0000
# Training step: 630, Output: -40.0463, Desired Output: -5000.0000
# Training step: 631, Output: -40.1306, Desired Output: -5000.0000
# Training step: 632, Output: -40.1755, Desired Output: -5000.0000
# Training step: 633, Output: -40.2568, Desired Output: -5000.0000
# Training step: 634, Output: -40.3212, Desired Output: -5000.0000
# Training step: 635, Output: -40.4072, Desired Output: -5000.0000
# Training step: 636, Output: -40.4452, Desired Output: -5000.0000
# Training step: 637, Output: -40.5092, Desired Output: -5000.0000
# Training step: 638, Output: -40.5426, Desired Output: -5000.0000
# Training step: 639, Output: -40.6209, Desired Output: -5000.0000
# Training step: 640, Output: -40.6607, Desired Output: -5000.0000
# Training step: 641, Output: -40.7410, Desired Output: -5000.0000
# Training step: 642, Output: -40.7848, Desired Output: -5000.0000
# Training step: 643, Output: -40.8675, Desired Output: -5000.0000
# Training step: 644, Output: -40.9360, Desired Output: -5000.0000
# Training step: 645, Output: -41.0005, Desired Output: -5000.0000
# Training step: 646, Output: -41.0424, Desired Output: -5000.0000
# Training step: 647, Output: -41.0777, Desired Output: -5000.0000
# Training step: 648, Output: -41.1461, Desired Output: -5000.0000
# Training step: 649, Output: -41.2203, Desired Output: -5000.0000
# Training step: 650, Output: -41.2086, Desired Output: -5000.0000
# Training step: 651, Output: -41.2697, Desired Output: -5000.0000
# Training step: 652, Output: -41.3344, Desired Output: -5000.0000
# Training step: 653, Output: -41.3889, Desired Output: -5000.0000
# Training step: 654, Output: -41.4275, Desired Output: -5000.0000
# Training step: 655, Output: -41.4762, Desired Output: -5000.0000
# Training step: 656, Output: -41.5785, Desired Output: -5000.0000
# Training step: 657, Output: -41.6335, Desired Output: -5000.0000
# Training step: 658, Output: -41.6992, Desired Output: -5000.0000
# Training step: 659, Output: -41.7315, Desired Output: -5000.0000
# Training step: 660, Output: -41.7826, Desired Output: -5000.0000
# Training step: 661, Output: -41.8644, Desired Output: -5000.0000
# Training step: 662, Output: -41.9376, Desired Output: -5000.0000
# Training step: 663, Output: -41.9905, Desired Output: -5000.0000
# Training step: 664, Output: -42.0412, Desired Output: -5000.0000
# Training step: 665, Output: -42.1232, Desired Output: -5000.0000
# Training step: 666, Output: -42.1853, Desired Output: -5000.0000
# Training step: 667, Output: -42.2315, Desired Output: -5000.0000
# Training step: 668, Output: -42.2817, Desired Output: -5000.0000
# Training step: 669, Output: -42.3323, Desired Output: -5000.0000
# Training step: 670, Output: -42.3589, Desired Output: -5000.0000
# Training step: 671, Output: -42.4075, Desired Output: -5000.0000
# Training step: 672, Output: -42.4526, Desired Output: -5000.0000
# Training step: 673, Output: -42.5380, Desired Output: -5000.0000
# Training step: 674, Output: -42.6045, Desired Output: -5000.0000
# Training step: 675, Output: -42.6815, Desired Output: -5000.0000
# Training step: 676, Output: -42.7195, Desired Output: -5000.0000
# Training step: 677, Output: -42.7918, Desired Output: -5000.0000
# Training step: 678, Output: -42.8437, Desired Output: -5000.0000
# Training step: 679, Output: -42.8843, Desired Output: -5000.0000
# Training step: 680, Output: -43.0030, Desired Output: -5000.0000
# Training step: 681, Output: -43.0385, Desired Output: -5000.0000
# Training step: 682, Output: -43.0719, Desired Output: -5000.0000
# Training step: 683, Output: -43.0835, Desired Output: -5000.0000
# Training step: 684, Output: -43.2106, Desired Output: -5000.0000
# Training step: 685, Output: -43.2667, Desired Output: -5000.0000
# Training step: 686, Output: -43.3202, Desired Output: -5000.0000
# Training step: 687, Output: -43.3635, Desired Output: -5000.0000
# Training step: 688, Output: -43.4269, Desired Output: -5000.0000
# Training step: 689, Output: -43.4632, Desired Output: -5000.0000
# Training step: 690, Output: -43.5393, Desired Output: -5000.0000
# Training step: 691, Output: -43.5898, Desired Output: -5000.0000
# Training step: 692, Output: -43.6425, Desired Output: -5000.0000
# Training step: 693, Output: -43.7283, Desired Output: -5000.0000
# Training step: 694, Output: -43.7758, Desired Output: -5000.0000
# Training step: 695, Output: -43.8591, Desired Output: -5000.0000
# Training step: 696, Output: -43.8648, Desired Output: -5000.0000
# Training step: 697, Output: -43.9492, Desired Output: -5000.0000
# Training step: 698, Output: -43.9891, Desired Output: -5000.0000
# Training step: 699, Output: -44.0380, Desired Output: -5000.0000
# Training step: 700, Output: -44.0993, Desired Output: -5000.0000
# Training step: 701, Output: -44.1814, Desired Output: -5000.0000
# Training step: 702, Output: -44.2099, Desired Output: -5000.0000
# Training step: 703, Output: -44.2578, Desired Output: -5000.0000
# Training step: 704, Output: -44.3542, Desired Output: -5000.0000
# Training step: 705, Output: -44.3880, Desired Output: -5000.0000
# Training step: 706, Output: -44.4194, Desired Output: -5000.0000
# Training step: 707, Output: -44.4571, Desired Output: -5000.0000
# Training step: 708, Output: -44.4968, Desired Output: -5000.0000
# Training step: 709, Output: -44.5580, Desired Output: -5000.0000
# Training step: 710, Output: -44.6291, Desired Output: -5000.0000
# Training step: 711, Output: -44.6771, Desired Output: -5000.0000
# Training step: 712, Output: -44.7409, Desired Output: -5000.0000
# Training step: 713, Output: -44.8096, Desired Output: -5000.0000
# Training step: 714, Output: -44.8965, Desired Output: -5000.0000
# Training step: 715, Output: -44.9523, Desired Output: -5000.0000
# Training step: 716, Output: -45.0228, Desired Output: -5000.0000
# Training step: 717, Output: -45.0833, Desired Output: -5000.0000
# Training step: 718, Output: -45.1323, Desired Output: -5000.0000
# Training step: 719, Output: -45.2256, Desired Output: -5000.0000
# Training step: 720, Output: -45.2460, Desired Output: -5000.0000
# Training step: 721, Output: -45.3558, Desired Output: -5000.0000
# Training step: 722, Output: -45.3896, Desired Output: -5000.0000
# Training step: 723, Output: -45.4482, Desired Output: -5000.0000
# Training step: 724, Output: -45.5065, Desired Output: -5000.0000
# Training step: 725, Output: -45.5179, Desired Output: -5000.0000
# Training step: 726, Output: -45.6041, Desired Output: -5000.0000
# Training step: 727, Output: -45.6645, Desired Output: -5000.0000
# Training step: 728, Output: -45.7503, Desired Output: -5000.0000
# Training step: 729, Output: -45.8072, Desired Output: -5000.0000
# Training step: 730, Output: -45.8556, Desired Output: -5000.0000
# Training step: 731, Output: -45.9500, Desired Output: -5000.0000
# Training step: 732, Output: -46.0515, Desired Output: -5000.0000
# Training step: 733, Output: -46.0937, Desired Output: -5000.0000
# Training step: 734, Output: -46.1527, Desired Output: -5000.0000
# Training step: 735, Output: -46.2127, Desired Output: -5000.0000
# Training step: 736, Output: -46.2677, Desired Output: -5000.0000
# Training step: 737, Output: -46.3352, Desired Output: -5000.0000
# Training step: 738, Output: -46.3884, Desired Output: -5000.0000
# Training step: 739, Output: -46.4291, Desired Output: -5000.0000
# Training step: 740, Output: -46.4479, Desired Output: -5000.0000
# ...
# Training step: 1284, Output: -272.8898, Desired Output: -5000.0000
# Training step: 1285, Output: -272.9034, Desired Output: -5000.0000
# Training step: 1286, Output: -272.8812, Desired Output: -5000.0000
# Training step: 1287, Output: -272.9143, Desired Output: -5000.0000
# Training step: 1288, Output: -272.9012, Desired Output: -5000.0000
# Training step: 1289, Output: -272.8630, Desired Output: -5000.0000
# Training step: 1290, Output: -272.9275, Desired Output: -5000.0000
# Training step: 1291, Output: -272.9667, Desired Output: -5000.0000
# Training step: 1292, Output: -272.9688, Desired Output: -5000.0000
# Training step: 1293, Output: -272.9462, Desired Output: -5000.0000
# Training step: 1294, Output: -272.9904, Desired Output: -5000.0000
# Training step: 1295, Output: -272.9976, Desired Output: -5000.0000
# Training step: 1296, Output: -273.0091, Desired Output: -5000.0000
# Training step: 1297, Output: -273.0242, Desired Output: -5000.0000
# Training step: 1298, Output: -273.0061, Desired Output: -5000.0000
# Training step: 1299, Output: -273.0533, Desired Output: -5000.0000
# Training step: 1300, Output: -273.0740, Desired Output: -5000.0000
# Training step: 1301, Output: -273.0432, Desired Output: -5000.0000
# Training step: 1302, Output: -273.1169, Desired Output: -5000.0000
# Training step: 1303, Output: -273.1063, Desired Output: -5000.0000
# Training step: 1304, Output: -273.1043, Desired Output: -5000.0000
# Training step: 1305, Output: -273.0978, Desired Output: -5000.0000
# Training step: 1306, Output: -273.0959, Desired Output: -5000.0000
# Training step: 1307, Output: -273.1044, Desired Output: -5000.0000
# Training step: 1308, Output: -273.1576, Desired Output: -5000.0000
# Training step: 1309, Output: -273.1597, Desired Output: -5000.0000
# Training step: 1310, Output: -273.0330, Desired Output: -5000.0000
# Training step: 1311, Output: -273.0952, Desired Output: -5000.0000
# Training step: 1312, Output: -273.1279, Desired Output: -5000.0000
# Training step: 1313, Output: -273.1433, Desired Output: -5000.0000
# Training step: 1314, Output: -273.1673, Desired Output: -5000.0000
# Training step: 1315, Output: -273.1498, Desired Output: -5000.0000
# Training step: 1316, Output: -273.1780, Desired Output: -5000.0000
# Training step: 1317, Output: -273.2233, Desired Output: -5000.0000
# Training step: 1318, Output: -273.2439, Desired Output: -5000.0000
# Training step: 1319, Output: -273.2104, Desired Output: -5000.0000
# Training step: 1320, Output: -273.2549, Desired Output: -5000.0000
# Training step: 1321, Output: -273.2629, Desired Output: -5000.0000
# Training step: 1322, Output: -273.2767, Desired Output: -5000.0000
# Training step: 1323, Output: -273.3049, Desired Output: -5000.0000
# Training step: 1324, Output: -273.2929, Desired Output: -5000.0000
# Training step: 1325, Output: -273.3347, Desired Output: -5000.0000
# Training step: 1326, Output: -273.3084, Desired Output: -5000.0000
# Training step: 1327, Output: -273.3082, Desired Output: -5000.0000
# Training step: 1328, Output: -273.3161, Desired Output: -5000.0000
# Training step: 1329, Output: -273.2956, Desired Output: -5000.0000
# Training step: 1330, Output: -273.3370, Desired Output: -5000.0000
# Training step: 1331, Output: -273.3340, Desired Output: -5000.0000
# Training step: 1332, Output: -273.3663, Desired Output: -5000.0000
# Training step: 1333, Output: -273.3281, Desired Output: -5000.0000
# Training step: 1334, Output: -273.3277, Desired Output: -5000.0000
# Training step: 1335, Output: -273.3224, Desired Output: -5000.0000
# Training step: 1336, Output: -273.3373, Desired Output: -5000.0000
# Training step: 1337, Output: -273.3369, Desired Output: -5000.0000
# Training step: 1338, Output: -273.3327, Desired Output: -5000.0000
# Training step: 1339, Output: -273.3319, Desired Output: -5000.0000
# Training step: 1340, Output: -273.3437, Desired Output: -5000.0000
# Training step: 1341, Output: -273.3951, Desired Output: -5000.0000
# Training step: 1342, Output: -273.4384, Desired Output: -5000.0000
# Training step: 1343, Output: -273.4328, Desired Output: -5000.0000
# Training step: 1344, Output: -273.3478, Desired Output: -5000.0000
# Training step: 1345, Output: -273.4495, Desired Output: -5000.0000
# Training step: 1346, Output: -273.4511, Desired Output: -5000.0000
# Training step: 1347, Output: -273.4509, Desired Output: -5000.0000
# Training step: 1348, Output: -273.4055, Desired Output: -5000.0000
# Training step: 1349, Output: -273.4150, Desired Output: -5000.0000
# Training step: 1350, Output: -273.4196, Desired Output: -5000.0000
# Training step: 1351, Output: -273.4384, Desired Output: -5000.0000
# Training step: 1352, Output: -273.4645, Desired Output: -5000.0000
# Training step: 1353, Output: -273.4818, Desired Output: -5000.0000
# Training step: 1354, Output: -273.5455, Desired Output: -5000.0000
# Training step: 1355, Output: -273.4820, Desired Output: -5000.0000
# Training step: 1356, Output: -273.5219, Desired Output: -5000.0000
# Training step: 1357, Output: -273.5492, Desired Output: -5000.0000
# Training step: 1358, Output: -273.5063, Desired Output: -5000.0000
# Training step: 1359, Output: -273.4922, Desired Output: -5000.0000
# Training step: 1360, Output: -273.4912, Desired Output: -5000.0000
# Training step: 1361, Output: -273.4802, Desired Output: -5000.0000
# Training step: 1362, Output: -273.5470, Desired Output: -5000.0000
# Training step: 1363, Output: -273.5461, Desired Output: -5000.0000
# Training step: 1364, Output: -273.5516, Desired Output: -5000.0000
# Training step: 1365, Output: -273.6009, Desired Output: -5000.0000
# Training step: 1366, Output: -273.5486, Desired Output: -5000.0000
# Training step: 1367, Output: -273.5827, Desired Output: -5000.0000
# Training step: 1368, Output: -273.5692, Desired Output: -5000.0000
# Training step: 1369, Output: -273.5959, Desired Output: -5000.0000
# Training step: 1370, Output: -273.6058, Desired Output: -5000.0000
# Training step: 1371, Output: -273.6148, Desired Output: -5000.0000
# Training step: 1372, Output: -273.5717, Desired Output: -5000.0000
# Training step: 1373, Output: -273.5737, Desired Output: -5000.0000
# Training step: 1374, Output: -273.6035, Desired Output: -5000.0000
# Training step: 1375, Output: -273.6638, Desired Output: -5000.0000
# Training step: 1376, Output: -273.6320, Desired Output: -5000.0000
# Training step: 1377, Output: -273.6791, Desired Output: -5000.0000
# Training step: 1378, Output: -273.7081, Desired Output: -5000.0000
# Training step: 1379, Output: -273.7231, Desired Output: -5000.0000
# Training step: 1380, Output: -273.7059, Desired Output: -5000.0000
# Training step: 1381, Output: -273.7397, Desired Output: -5000.0000
# Training step: 1382, Output: -273.7011, Desired Output: -5000.0000
# Training step: 1383, Output: -273.7219, Desired Output: -5000.0000
# Training step: 1384, Output: -273.7318, Desired Output: -5000.0000
# Training step: 1385, Output: -273.6982, Desired Output: -5000.0000
# Training step: 1386, Output: -273.7685, Desired Output: -5000.0000
# Training step: 1387, Output: -273.7643, Desired Output: -5000.0000
# Training step: 1388, Output: -273.6915, Desired Output: -5000.0000
# Training step: 1389, Output: -273.7292, Desired Output: -5000.0000
# Training step: 1390, Output: -273.7302, Desired Output: -5000.0000
# Training step: 1391, Output: -273.7766, Desired Output: -5000.0000
# Training step: 1392, Output: -273.7953, Desired Output: -5000.0000
# Training step: 1393, Output: -273.8293, Desired Output: -5000.0000
# Training step: 1394, Output: -273.7897, Desired Output: -5000.0000
# Training step: 1395, Output: -273.8263, Desired Output: -5000.0000
# Training step: 1396, Output: -273.8204, Desired Output: -5000.0000
# Training step: 1397, Output: -273.8138, Desired Output: -5000.0000
# Training step: 1398, Output: -273.8169, Desired Output: -5000.0000
# Training step: 1399, Output: -273.7575, Desired Output: -5000.0000
# Training step: 1400, Output: -273.8022, Desired Output: -5000.0000
# Training step: 1401, Output: -273.7536, Desired Output: -5000.0000
# Training step: 1402, Output: -273.7558, Desired Output: -5000.0000
# Training step: 1403, Output: -273.8004, Desired Output: -5000.0000
# Training step: 1404, Output: -273.8299, Desired Output: -5000.0000
# Training step: 1405, Output: -273.8289, Desired Output: -5000.0000
# Training step: 1406, Output: -273.8932, Desired Output: -5000.0000
# Training step: 1407, Output: -273.9385, Desired Output: -5000.0000
# Training step: 1408, Output: -273.9318, Desired Output: -5000.0000
# Training step: 1409, Output: -273.9462, Desired Output: -5000.0000
# Training step: 1410, Output: -273.9636, Desired Output: -5000.0000
# Training step: 1411, Output: -273.9593, Desired Output: -5000.0000
# Training step: 1412, Output: -273.9611, Desired Output: -5000.0000
# Training step: 1413, Output: -273.9146, Desired Output: -5000.0000
# Training step: 1414, Output: -273.9135, Desired Output: -5000.0000
# Training step: 1415, Output: -274.0038, Desired Output: -5000.0000
# Training step: 1416, Output: -273.9788, Desired Output: -5000.0000
# Training step: 1417, Output: -273.9979, Desired Output: -5000.0000
# Training step: 1418, Output: -274.0058, Desired Output: -5000.0000
# Training step: 1419, Output: -274.0193, Desired Output: -5000.0000
# Training step: 1420, Output: -273.9953, Desired Output: -5000.0000
# Training step: 1421, Output: -273.9673, Desired Output: -5000.0000
# Training step: 1422, Output: -273.9680, Desired Output: -5000.0000
# Training step: 1423, Output: -273.9871, Desired Output: -5000.0000
# Training step: 1424, Output: -274.0117, Desired Output: -5000.0000
# Training step: 1425, Output: -274.0636, Desired Output: -5000.0000
# Training step: 1426, Output: -274.0847, Desired Output: -5000.0000
# Training step: 1427, Output: -274.0743, Desired Output: -5000.0000
# Training step: 1428, Output: -274.0396, Desired Output: -5000.0000
# Training step: 1429, Output: -274.0737, Desired Output: -5000.0000
# Training step: 1430, Output: -274.1148, Desired Output: -5000.0000
# Training step: 1431, Output: -274.0883, Desired Output: -5000.0000
# Training step: 1432, Output: -274.0966, Desired Output: -5000.0000
# Training step: 1433, Output: -274.0850, Desired Output: -5000.0000
# Training step: 1434, Output: -274.1420, Desired Output: -5000.0000
# Training step: 1435, Output: -274.0508, Desired Output: -5000.0000
# Training step: 1436, Output: -274.1285, Desired Output: -5000.0000
# Training step: 1437, Output: -274.0700, Desired Output: -5000.0000
# Training step: 1438, Output: -274.0977, Desired Output: -5000.0000
# Training step: 1439, Output: -274.1178, Desired Output: -5000.0000
# Training step: 1440, Output: -274.1091, Desired Output: -5000.0000
# Training step: 1441, Output: -274.0732, Desired Output: -5000.0000
# Training step: 1442, Output: -274.0777, Desired Output: -5000.0000
# Training step: 1443, Output: -274.1026, Desired Output: -5000.0000
# Training step: 1444, Output: -274.1125, Desired Output: -5000.0000
# Training step: 1445, Output: -274.1255, Desired Output: -5000.0000
# Training step: 1446, Output: -274.1363, Desired Output: -5000.0000
# Training step: 1447, Output: -274.0643, Desired Output: -5000.0000
# Training step: 1448, Output: -274.0913, Desired Output: -5000.0000
# Training step: 1449, Output: -274.1795, Desired Output: -5000.0000
# Training step: 1450, Output: -274.1820, Desired Output: -5000.0000
# Training step: 1451, Output: -274.2069, Desired Output: -5000.0000
# Training step: 1452, Output: -274.1870, Desired Output: -5000.0000
# Training step: 1453, Output: -274.2317, Desired Output: -5000.0000
# Training step: 1454, Output: -274.2750, Desired Output: -5000.0000
# Training step: 1455, Output: -274.3199, Desired Output: -5000.0000
# Training step: 1456, Output: -274.3037, Desired Output: -5000.0000
# Training step: 1457, Output: -274.2591, Desired Output: -5000.0000
# Training step: 1458, Output: -274.3131, Desired Output: -5000.0000
# Training step: 1459, Output: -274.3416, Desired Output: -5000.0000
# Training step: 1460, Output: -274.2745, Desired Output: -5000.0000
# Training step: 1461, Output: -274.3601, Desired Output: -5000.0000
# Training step: 1462, Output: -274.3114, Desired Output: -5000.0000
# Training step: 1463, Output: -274.3341, Desired Output: -5000.0000
# Training step: 1464, Output: -274.3873, Desired Output: -5000.0000
# Training step: 1465, Output: -274.3330, Desired Output: -5000.0000
# Training step: 1466, Output: -274.4006, Desired Output: -5000.0000
# Training step: 1467, Output: -274.4214, Desired Output: -5000.0000
# Training step: 1468, Output: -274.4312, Desired Output: -5000.0000
# Training step: 1469, Output: -274.4256, Desired Output: -5000.0000
# Training step: 1470, Output: -274.4196, Desired Output: -5000.0000
# Training step: 1471, Output: -274.4500, Desired Output: -5000.0000
# Training step: 1472, Output: -274.5292, Desired Output: -5000.0000
# Training step: 1473, Output: -274.4668, Desired Output: -5000.0000
# Training step: 1474, Output: -274.4969, Desired Output: -5000.0000
# Training step: 1475, Output: -274.4797, Desired Output: -5000.0000
# Training step: 1476, Output: -274.4713, Desired Output: -5000.0000
# Training step: 1477, Output: -274.4879, Desired Output: -5000.0000
# Training step: 1478, Output: -274.5177, Desired Output: -5000.0000
# Training step: 1479, Output: -274.5177, Desired Output: -5000.0000
# Training step: 1480, Output: -274.5533, Desired Output: -5000.0000
# Training step: 1481, Output: -274.5941, Desired Output: -5000.0000
# Training step: 1482, Output: -274.5928, Desired Output: -5000.0000
# Training step: 1483, Output: -274.5611, Desired Output: -5000.0000
# Training step: 1484, Output: -274.5701, Desired Output: -5000.0000
# Training step: 1485, Output: -274.5524, Desired Output: -5000.0000
# Training step: 1486, Output: -274.4792, Desired Output: -5000.0000
# Training step: 1487, Output: -274.4934, Desired Output: -5000.0000
# Training step: 1488, Output: -274.5208, Desired Output: -5000.0000
# Training step: 1489, Output: -274.5461, Desired Output: -5000.0000
# Training step: 1490, Output: -274.5714, Desired Output: -5000.0000
# Training step: 1491, Output: -274.5196, Desired Output: -5000.0000
# Training step: 1492, Output: -274.4502, Desired Output: -5000.0000
# Training step: 1493, Output: -274.5149, Desired Output: -5000.0000
# Training step: 1494, Output: -274.5406, Desired Output: -5000.0000
# Training step: 1495, Output: -274.4816, Desired Output: -5000.0000
# Training step: 1496, Output: -274.5231, Desired Output: -5000.0000
# Training step: 1497, Output: -274.5463, Desired Output: -5000.0000
# Training step: 1498, Output: -274.5695, Desired Output: -5000.0000
# Training step: 1499, Output: -274.5598, Desired Output: -5000.0000
# [ 4.9848095e-01  2.2021733e-01 -7.5991843e-03  5.3257740e-01
#  -3.9327103e-03 -2.0469911e-03 -3.7610345e-04  7.7727234e-01
#   1.0009190e+00  2.1976765e-01 -2.2007446e-03  7.7931565e-01
#  -2.5273403e-03  4.9977794e-01  1.6437757e-03  7.8876042e-01
#   5.0025868e-01 -4.0971176e-03  3.1451097e-01  4.9859929e-01
#  -3.2310381e-03  2.2208013e-01 -2.4460549e-03 -3.5534683e-03
#   2.1995750e-01  1.0024499e+00  1.0024040e+00  1.0032889e+00
#   4.6665299e-01  5.3281820e-01 -5.7361270e-03 -3.9255670e-03
#  -4.5688981e-03  2.2049712e-01 -2.4524692e-03 -3.2913990e-03
#  -4.2636986e-03 -2.4880576e-03 -3.2495023e-03  2.2068937e-01
#   4.6671873e-01  3.1468698e-01 -2.6488875e-03 -3.6073260e-03
#  -1.3417462e-03  1.0028173e+00  5.3336453e-01 -1.0242434e-03
#  -4.2617694e-03 -6.1763241e-04  5.0004864e-01  2.1073589e-01
#   8.6814106e-01 -4.4147047e-04 -2.6966557e-03 -4.7666389e-03
#   6.8365538e-01  1.0029068e+00 -3.5545151e-03  2.1113005e-01
#   1.3126534e-01  1.3107094e-01 -3.6010882e-03  1.3228014e-01
#   7.7994603e-01 -3.8358208e-03 -5.7859728e-03  3.1398481e-01
#   3.1477189e-01 -3.5899458e-03  1.6255769e-03 -2.4157325e-03
#   5.0047690e-01 -3.6618689e-03 -2.1629718e-03  4.9852848e-01
#   1.0032015e+00  4.6724302e-01  9.9837393e-01 -6.5841194e-04
#   4.6658134e-01  4.9799573e-01  1.0013480e+00 -4.1973768e-03
#  -3.5083815e-03  4.6701655e-01  2.1031263e-01 -2.0116307e-03
#  -2.8627589e-03 -3.6640647e-03 -3.5960583e-03 -2.2391297e-03
#   2.1908660e-01  1.0029923e+00  5.0083953e-01 -1.1275874e-03
#   1.0743212e-03 -2.8675727e-03 -3.0312461e-03  6.8536603e-01]
