# %%
import pickle

solutions = {}

results = pickle.load(open("./solutions/SDP/SDP_Generation_500", "rb"))

print(results)

for result in results:
    solutions[result["graph_name"]] = result


def save_gpickle(file_path, python_object):
    with open(file_path, 'wb') as file:
        pickle.dump(python_object, file)

save_gpickle('./solutions/SDP/SDP_Generation_SATLIB', solutions)
# Out:
# [{'graph_name': 'CBS_k3_n100_m403_b50_58', 'SDP_solution': tensor([0.4219, 0.6901, 0.1524,  ..., 0.5001, 0.1119, 0.6523]), 'time_taken': 26.88179063796997}, {'graph_name': 'CBS_k3_n100_m441_b90_771', 'SDP_solution': tensor([0.4532, 0.5529, 0.3474,  ..., 0.7517, 0.3085, 0.2933]), 'time_taken': 36.78540563583374}, {'graph_name': 'CBS_k3_n100_m418_b10_512', 'SDP_solution': tensor([0.3702, 0.5768, 0.3584,  ..., 0.3288, 0.7416, 0.2350]), 'time_taken': 31.021774291992188}, {'graph_name': 'CBS_k3_n100_m423_b10_718', 'SDP_solution': tensor([0.4307, 0.2629, 0.6154,  ..., 0.5713, 0.1699, 0.5679]), 'time_taken': 33.32815599441528}, {'graph_name': 'CBS_k3_n100_m403_b50_737', 'SDP_solution': tensor([0.7119, 0.2891, 0.4761,  ..., 0.3557, 0.5126, 0.6088]), 'time_taken': 27.171883583068848}, {'graph_name': 'CBS_k3_n100_m418_b90_982', 'SDP_solution': tensor([0.3300, 0.4954, 0.5614,  ..., 0.6223, 0.4119, 0.3526]), 'time_taken': 30.94936752319336}, {'graph_name': 'CBS_k3_n100_m423_b50_757', 'SDP_solution': tensor([0.4083, 0.6144, 0.2537,  ..., 0.3593, 0.4266, 0.4905]), 'time_taken': 32.93511652946472}, {'graph_name': 'CBS_k3_n100_m403_b30_404', 'SDP_solution': tensor([0.7007, 0.4614, 0.2465,  ..., 0.4573, 0.6219, 0.3296]), 'time_taken': 28.079763889312744}, {'graph_name': 'CBS_k3_n100_m429_b50_277', 'SDP_solution': tensor([0.4821, 0.4584, 0.4397,  ..., 0.2216, 0.5003, 0.6583]), 'time_taken': 37.481226682662964}, {'graph_name': 'CBS_k3_n100_m423_b70_612', 'SDP_solution': tensor([0.4320, 0.2233, 0.6185,  ..., 0.7036, 0.3390, 0.2312]), 'time_taken': 32.80349946022034}, {'graph_name': 'CBS_k3_n100_m441_b10_727', 'SDP_solution': tensor([0.3124, 0.3467, 0.6229,  ..., 0.3812, 0.4982, 0.4027]), 'time_taken': 38.863404512405396}, {'graph_name': 'CBS_k3_n100_m441_b30_300', 'SDP_solution': tensor([0.3887, 0.5432, 0.3923,  ..., 0.8491, 0.3061, 0.1691]), 'time_taken': 37.84119701385498}, {'graph_name': 'CBS_k3_n100_m441_b50_842', 'SDP_solution': tensor([0.4401, 0.2486, 0.5245,  ..., 0.7203, 0.0472, 0.4457]), 'time_taken': 40.28399896621704}, {'graph_name': 'CBS_k3_n100_m403_b70_451', 'SDP_solution': tensor([0.5659, 0.5844, 0.3088,  ..., 0.4154, 0.5492, 0.4946]), 'time_taken': 28.324243783950806}, {'graph_name': 'CBS_k3_n100_m441_b30_610', 'SDP_solution': tensor([0.4038, 0.4294, 0.5129,  ..., 0.2956, 0.6973, 0.3532]), 'time_taken': 38.844149112701416}, {'graph_name': 'CBS_k3_n100_m441_b70_262', 'SDP_solution': tensor([0.4353, 0.5664, 0.2173,  ..., 0.5675, 0.3833, 0.2682]), 'time_taken': 38.19698786735535}, {'graph_name': 'CBS_k3_n100_m423_b90_847', 'SDP_solution': tensor([0.2886, 0.5759, 0.4774,  ..., 0.6641, 0.4362, 0.2417]), 'time_taken': 34.38724637031555}, {'graph_name': 'CBS_k3_n100_m423_b50_588', 'SDP_solution': tensor([0.4499, 0.4749, 0.3893,  ..., 0.6369, 0.4403, 0.2369]), 'time_taken': 32.8094367980957}, {'graph_name': 'CBS_k3_n100_m403_b50_999', 'SDP_solution': tensor([0.3915, 0.8561, 0.1274,  ..., 0.3811, 0.9046, 0.0894]), 'time_taken': 28.105154991149902}, {'graph_name': 'CBS_k3_n100_m403_b50_545', 'SDP_solution': tensor([0.2766, 0.5524, 0.6225,  ..., 0.5198, 0.4346, 0.4972]), 'time_taken': 27.952293157577515}, {'graph_name': 'CBS_k3_n100_m423_b90_453', 'SDP_solution': tensor([0.3428, 0.6360, 0.4050,  ..., 1.0000, 0.1919, 0.1919]), 'time_taken': 32.211084604263306}, {'graph_name': 'CBS_k3_n100_m411_b70_341', 'SDP_solution': tensor([0.5409, 0.3903, 0.5786,  ..., 0.2787, 0.4988, 0.7323]), 'time_taken': 29.55167055130005}, {'graph_name': 'CBS_k3_n100_m423_b70_709', 'SDP_solution': tensor([0.2936, 0.4200, 0.6044,  ..., 0.2185, 0.4862, 0.6132]), 'time_taken': 32.37259387969971}, {'graph_name': 'CBS_k3_n100_m411_b70_441', 'SDP_solution': tensor([0.7211, 0.3719, 0.1167,  ..., 0.3068, 0.3520, 0.5509]), 'time_taken': 29.611765146255493}, {'graph_name': 'CBS_k3_n100_m435_b70_984', 'SDP_solution': tensor([0.4027, 0.5399, 0.3076,  ..., 0.3998, 0.3600, 0.4904]), 'time_taken': 34.84460091590881}, {'graph_name': 'CBS_k3_n100_m403_b90_616', 'SDP_solution': tensor ...
