# %%
import os
import re
import networkx as nx
import pickle

input_graph_directory = "../graphs/gnm_random_graph_scalability"
target_graph_directory = "../../fobc/graphs/gnm_random_graph_scalability"


def process_gpickle(file_path, target_path):
    filename = os.path.basename(file_path)
    print(
        "Graph ",
        file_path,
        "is being imported ...",
    )
    with open(file_path, "rb") as f:
        G = pickle.load(f)

        G = nx.convert_node_labels_to_integers(G, first_label=1, ordering="default")

        filename = f"{filename[:-8]}.clq"
        print(f"Generating graph: {filename}")
        print(target_path)
        if not os.path.exists(target_path):
            os.makedirs(target_path)
        with open(target_path + filename, "w") as f:
            # write the header
            f.write("p EDGE {} {}\n".format(G.number_of_nodes(), G.number_of_edges()))
            # now write all edges
            for u, v in G.edges():
                f.write("e {} {}\n".format(u, v))


for root, dirs, files in os.walk(input_graph_directory):
    print(target_graph_directory, root[len(input_graph_directory) + 1 :])
    new_target = os.path.join(
        target_graph_directory, root[len(input_graph_directory) + 1 :] + "/"
    )
    print(new_target)
    for filename in files:
        if filename.endswith(".gpickle"):
            process_gpickle(os.path.join(root, filename), new_target)
# Out:
# ../../fobc/graphs/gnm_random_graph_scalability
# /
# ../../fobc/graphs/gnm_random_graph_scalability gnm_1500_562125
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1500_562125/GNM_1500_562125_3.gpickle is being imported ...
# Generating graph: GNM_1500_562125_3.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1500_562125/GNM_1500_562125_0.gpickle is being imported ...
# Generating graph: GNM_1500_562125_0.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1500_562125/GNM_1500_562125_4.gpickle is being imported ...
# Generating graph: GNM_1500_562125_4.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1500_562125/GNM_1500_562125_1.gpickle is being imported ...
# Generating graph: GNM_1500_562125_1.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1500_562125/GNM_1500_562125_2.gpickle is being imported ...
# Generating graph: GNM_1500_562125_2.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1500_562125/
# ../../fobc/graphs/gnm_random_graph_scalability gnm_50_613
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_50_613/GNM_50_613_2.gpickle is being imported ...
# Generating graph: GNM_50_613_2.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_50_613/GNM_50_613_4.gpickle is being imported ...
# Generating graph: GNM_50_613_4.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_50_613/GNM_50_613_3.gpickle is being imported ...
# Generating graph: GNM_50_613_3.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_50_613/GNM_50_613_0.gpickle is being imported ...
# Generating graph: GNM_50_613_0.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_50_613/GNM_50_613_1.gpickle is being imported ...
# Generating graph: GNM_50_613_1.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_50_613/
# ../../fobc/graphs/gnm_random_graph_scalability gnm_2000_999500
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_2000_999500/GNM_2000_999500_0.gpickle is being imported ...
# Generating graph: GNM_2000_999500_0.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_2000_999500/GNM_2000_999500_4.gpickle is being imported ...
# Generating graph: GNM_2000_999500_4.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_2000_999500/GNM_2000_999500_1.gpickle is being imported ...
# Generating graph: GNM_2000_999500_1.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_2000_999500/GNM_2000_999500_2.gpickle is being imported ...
# Generating graph: GNM_2000_999500_2.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_2000_999500/GNM_2000_999500_3.gpickle is being imported ...
# Generating graph: GNM_2000_999500_3.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_2000_999500/
# ../../fobc/graphs/gnm_random_graph_scalability gnm_500_62375
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_500_62375/GNM_500_62375_2.gpickle is being imported ...
# Generating graph: GNM_500_62375_2.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_500_62375/GNM_500_62375_4.gpickle is being imported ...
# Generating graph: GNM_500_62375_4.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_500_62375/GNM_500_62375_1.gpickle is being imported ...
# Generating graph: GNM_500_62375_1.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_500_62375/GNM_500_62375_0.gpickle is being imported ...
# Generating graph: GNM_500_62375_0.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_500_62375/GNM_500_62375_3.gpickle is being imported ...
# Generating graph: GNM_500_62375_3.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_500_62375/
# ../../fobc/graphs/gnm_random_graph_scalability gnm_1000_249750
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1000_249750/GNM_1000_249750_2.gpickle is being imported ...
# Generating graph: GNM_1000_249750_2.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1000_249750/GNM_1000_249750_4.gpickle is being imported ...
# Generating graph: GNM_1000_249750_4.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1000_249750/GNM_1000_249750_1.gpickle is being imported ...
# Generating graph: GNM_1000_249750_1.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1000_249750/GNM_1000_249750_0.gpickle is being imported ...
# Generating graph: GNM_1000_249750_0.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
# Graph  ../graphs/gnm_random_graph_scalability/gnm_1000_249750/GNM_1000_249750_3.gpickle is being imported ...
# Generating graph: GNM_1000_249750_3.clq
# ../../fobc/graphs/gnm_random_graph_scalability/gnm_1000_249750/
